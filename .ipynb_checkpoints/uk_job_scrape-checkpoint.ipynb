# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
import re

import time
from tqdm import tqdm_notebook

#Function definitions

def extract_jobtitle_from_result(result):
    try:
        return result.find('a',attrs={'class':'jobtitle'})['title']
    except:
        return np.nan

def extract_location_from_result(result):    
    try:
        return result.find('span',attrs={'class':'location accessible-contrast-color-location'}).text
    except:
        return np.nan
        
def extract_salary_from_result(result):
    try:
        return result.find('span',attrs={'class':"salaryText"}).text.strip() 
    except: 
        return np.nan

def extract_company_from_result(result):
    try:
        return result.find('span',attrs={'class':"company"}).text.strip()  
    except:
        return np.nan
    
def extract_summary_from_result(result):
    try:
        return result.find('div',attrs={'class':re.compile(r'^jobsearch-jobDescriptionText?')})   
    except:
        return np.nan
    
def extract_href_from_result(result):
    try:
        return result.find('a')['href']   
    except:
        return np.nan

# %%
states_to_use = ['England','Wales','Scotland','Northern Ireland']
list_of_searchwords = ['data+scientist','data+analyst','research+scientist','business+intelligence','machine+learning']

# %%
#Determining number of jobs per state,region, area etc

jobs_in_state = {'state':[],'role':[],'jobs':[]}

for state in tqdm_notebook(states_to_use):
    
    for role in list_of_searchwords:
    

        count_url = f'https://www.indeed.co.uk/jobs?as_and=&as_phr=&as_any=&as_not=&as_ttl={role}&as_cmp=&jt=all&st=&as_src=&salary=&radius=5000&l={state}&fromage=any&limit=50&sort=&psf=advsrch&filter=0'

        time.sleep(np.random.randint(0,2))

        counter = requests.get(count_url)
        soup_count = BeautifulSoup(counter.text,'html.parser')

        try:
            record_string = soup_count.find_all('div',attrs={'id':"searchCountPages"})[0].text
            record_string = record_string.replace(",","")
            max_results_per_city = int(re.search(r"(\w+)\sjobs",record_string).group(1))
            
        except:
            max_results_per_city = np.nan
            
        #try:
            #true_pages = int(soup_count.find_all("span",class_="pn")[-2].text)
            #print(true_pages,max_results_per_city)
            
        #except:
            #true_pages = 0
            #print(true_pages)

        jobs_in_state['state'].append(state)
        jobs_in_state['role'].append(role)
        jobs_in_state['jobs'].append(max_results_per_city)
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))

# %%
job_nums = pd.DataFrame(jobs_in_state).sort_values(by='jobs',ascending=False)

state_searchlist= job_nums.groupby(["state"]).mean().sort_values(by="jobs",ascending=True).index.to_list()
role_searchlist = job_nums.groupby(["role"]).mean().sort_values(by="jobs",ascending=True).index.to_list()
job_nums[job_nums.jobs.isna()]
# Out:
# Empty DataFrame
# Columns: [state, role, jobs]
# Index: []

# %%
df_dict = {'job_title':[],'job_category':[],
           'company':[],'location':[],
           'region':[],'salary':[],
           'link':[],'summary':[]}

#url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 294 # Set this to a high-value (5000) to generate more results. 
# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

all_files = []

for state in tqdm_notebook(state_searchlist):

    for role in tqdm_notebook(role_searchlist):
        
        count_url = f'https://www.indeed.co.uk/jobs?as_ttl={role}&jt=all&radius=5000&l={state}&fromage=any&limit=50&start=0&filter=0'

        time.sleep(np.random.randint(0,1))

        counter = requests.get(count_url)
        soup_count = BeautifulSoup(counter.text,'html.parser')

        try:
            record_string = soup_count.find_all('div',attrs={'id':"searchCountPages"})[0].text
            record_string = record_string.replace(",","")
            max_results_per_city = int(re.search(r"(\w+)\sjobs",record_string).group(1))
        except:
            max_results_per_city = 1
         
        for start in tqdm_notebook(range(0, max_results_per_city,50)):
            time.sleep(np.random.randint(0,1))
            
            URL = f'https://www.indeed.co.uk/jobs?as_ttl={role}&jt=all&radius=5000&l={state}&fromage=any&limit=50&start={start}&filter=0'
            
            results = requests.get(URL)
            soup = BeautifulSoup(results.text,'html.parser')
                        
            #print(city,int(max_results_per_city))
            
            #print(state,start,soup.find_all('div',attrs={'id':"searchCountPages"})[0].text)
            
            if len(soup.find_all('span',attrs={'class':'salary no-wrap'})) == 0:
                
                pass
                
            else:
                for jobtile in soup.find_all('div',attrs={'class':re.compile(r'^jobsearch-Serp.*unified.*')}):

                    if len(jobtile.find_all('span',attrs={'class':'salary no-wrap'})) == 0:
                        pass
                    else:
                        all_files.append(jobtile)
                        df_dict['job_category'].append(" ".join(role.split("+")).title())
                        df_dict['region'].append(" ".join(state.split("+")).title())
                        
                        detail_link = "https://www.indeed.co.uk/"+extract_href_from_result(jobtile)
                        df_dict['link'].append(detail_link)
                        time.sleep(np.random.randint(0,1))
                        detailgrab = requests.get(detail_link)
                        soup_detail = BeautifulSoup(detailgrab.text,'html.parser')
                        
                        try:
                            df_dict['summary'].append(extract_summary_from_result(soup_detail).text)
                        except:
                            df_dict['summary'].append(np.nan)
# Out:
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=19), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=33), HTML(value='')))

# %%
for x in all_files:
    try:
        df_dict['location'].append(extract_location_from_result(x))
    except:
        df_dict['location'].append(np.nan)
        
    try:
        df_dict['company'].append(extract_company_from_result(x))
    except:
        df_dict['company'].append(np.nan)
        
    try:
        df_dict['salary'].append(extract_salary_from_result(x))
        
    except:
        df_dict['salary'].append(np.nan)

    try:
        df_dict['job_title'].append(extract_jobtitle_from_result(x))
        
    except:
        df_dict['job_title'].append(np.nan)

# %%
df = pd.DataFrame(df_dict)

np.sum(df[df.salary.notna()].duplicated() ==False)*100/df.shape[0]

#df = df[df.salary.notna()]

#df = df[df.duplicated()==False]

#df.to_csv("uk_jobs.csv",index=False)
# Out:
# 78.6697247706422

# %%
df[df.duplicated()==False]
# Out:
#                                               job_title  \
# 0     Sport and Exercise Scientist (Teaching & Resea...
# 1          Software Test Engineer – AI Machine Learning
# 2                  Java Consultant ( Machine Learning )
# 3                 Business Intelligence Analyst (Omagh)
# 4                         Business Intelligence Analyst
# 5                         Business Intelligence Analyst
# 6                         Business Intelligence Analyst
# 7                               Data Scientist ( Java )
# 8          Data Scientist ( 12 month Contract, Belfast)
# 9                               Data Scientist ( Java )
# 10      Data Scientist ( Multinational Business – NEW )
# 11                            Data Analyst ( Power BI )
# 12                                         Data Analyst
# 13                   Cost Analyst – Junior Data Analyst
# 14                                         Data Analyst
# 15                                         Data Analyst
# 16    Senior Research Scientist, South Wales, Contra...
# 17    Senior Research Scientist, Newport South Wales...
# 18    Sport and Exercise Scientist (Teaching & Resea...
# 19                            Machine Learning Engineer
# 20                      Business Intelligence Assistant
# 21                      Business Intelligence Assistant
# 22                        Business Intelligence Manager
# 23                        Business Intelligence Officer
# 24    Decision Support Accountant - Business Intelli...
# 25                        Business Intelligence Analyst
# 26                                       Data Scientist
# 27                                Junior Data Scientist
# 28                                   Stock/Data Analyst
# 29                                         DATA ANALYST
# ...                                                 ...
# 1898  Data Analyst with experience in NLP and sentim...
# 1899                                   SQL Data Analyst
# 1900                                       Data Analyst
# 1901                           Researcher /Data Analyst
# 1938  Data Analyst with experience in NLP and sentim...
# 1939                                   SQL Data Analyst
# 1940                                       Data Analyst
# 1941                           Researcher /Data Analyst
# 1978  Data Analyst with experience in NLP and sentim...
# 1979                                   SQL Data Analyst
# 1980                                       Data Analyst
# 1981                           Researcher /Data Analyst
# 2018  Data Analyst with experience in NLP and sentim...
# 2019                                   SQL Data Analyst
# 2020                                       Data Analyst
# 2021                           Researcher /Data Analyst
# 2058  Data Analyst with experience in NLP and sentim...
# 2059                                   SQL Data Analyst
# 2060                                       Data Analyst
# 2061                           Researcher /Data Analyst
# 2098  Data Analyst with experience in NLP and sentim...
# 2099                                   SQL Data Analyst
# 2100                                       Data Analyst
# 2101                           Researcher /Data Analyst
# 2138  Data Analyst with experience in NLP and sentim...
# 2139                                   SQL Data Analyst
# 2140                                       Data Analyst
# 2141                           Researcher /Data Analyst
# 2178  Data Analyst with experience in NLP and sentim...
# 2179                                   SQL Data Analyst
#
#                job_category                                company  \
# 0        Research Scientist                      Bangor University
# 1          Machine Learning                                VANRATH
# 2          Machine Learning                                VANRATH
# 3     Business Intelligence                               realTime
# 4     Business Intelligence                               Gi Group
# 5     Business Intelligence                               Gi Group
# 6     Business Intelligence                            Gi Group UK
# 7            Data Scientist                                VANRATH
# 8            Data Scientist                               realTime
# 9            Data Scientist                                VANRATH
# 10           Data Scientist                                VANRATH
# 11             Data Analyst                                VANRATH
# 12             Data Analyst                                VANRATH
# 13             Data Analyst        Abacus Professional Recruitment
# 14             Data Analyst                                VANRATH
# 15             Data Analyst                                VANRATH
# 16       Research Scientist                        Beecher Madden.
# 17       Research Scientist                        Beecher Madden.
# 18       Research Scientist            Prifysgol Bangor University
# 19         Machine Learning                             MARKETMATE
# 20    Business Intelligence                    Welsh Blood Service
# 21    Business Intelligence                    Welsh Blood Service
# 22    Business Intelligence            Bron Afon Community Housing
# 23    Business Intelligence                     Cardiff University
# 24    Business Intelligence  Aneurin Bevan University Health Board
# 25    Business Intelligence                             IntaPeople
# 26           Data Scientist                             We Predict
# 27           Data Scientist         Concept Information Technology
# 28             Data Analyst                 The Trade Centre Wales
# 29             Data Analyst                           Vibe Recruit
# ...                     ...                                    ...
# 1898           Data Analyst                                    ICF
# 1899           Data Analyst                  DBS Datamarketing Ltd
# 1900           Data Analyst            West London Waste Authority
# 1901           Data Analyst                Richmond Scientific Ltd
# 1938           Data Analyst                                    ICF
# 1939           Data Analyst                  DBS Datamarketing Ltd
# 1940           Data Analyst            West London Waste Authority
# 1941           Data Analyst                Richmond Scientific Ltd
# 1978           Data Analyst                                    ICF
# 1979           Data Analyst                  DBS Datamarketing Ltd
# 1980           Data Analyst            West London Waste Authority
# 1981           Data Analyst                Richmond Scientific Ltd
# 2018           Data Analyst                                    ICF
# 2019           Data Analyst                  DBS Datamarketing Ltd
# 2020           Data Analyst            West London Waste Authority
# 2021           Data Analyst                Richmond Scientific Ltd
# 2058           Data Analyst                                    ICF
# 2059           Data Analyst                  DBS Datamarketing Ltd
# 2060           Data Analyst            West London Waste Authority
# 2061           Data Analyst                Richmond Scientific Ltd
# 2098           Data Analyst                                    ICF
# 2099           Data Analyst                  DBS Datamarketing Ltd
# 2100           Data Analyst            West London Waste Authority
# 2101           Data Analyst                Richmond Scientific Ltd
# 2138           Data Analyst                                    ICF
# 2139           Data Analyst                  DBS Datamarketing Ltd
# 2140           Data Analyst            West London Waste Authority
# 2141           Data Analyst                Richmond Scientific Ltd
# 2178           Data Analyst                                    ICF
# 2179           Data Analyst                  DBS Datamarketing Ltd
#
#             location            region                    salary  \
# 0             Bangor  Northern Ireland  £50,132 - £58,089 a year
# 1            Belfast  Northern Ireland  £50,000 - £70,000 a year
# 2            Belfast  Northern Ireland  £55,000 - £67,500 a year
# 3      County Tyrone  Northern Ireland  £30,000 - £45,000 a year
# 4              Omagh  Northern Ireland            £30,000 a year
# 5              Omagh  Northern Ireland            £30,000 a year
# 6                NaN  Northern Ireland  £25,000 - £30,000 a year
# 7            Belfast  Northern Ireland  £65,000 - £70,000 a year
# 8            Belfast  Northern Ireland  £75,000 - £85,000 a year
# 9            Belfast  Northern Ireland  £65,000 - £70,000 a year
# 10           Belfast  Northern Ireland  £30,000 - £45,000 a year
# 11           Belfast  Northern Ireland  £28,000 - £30,000 a year
# 12           Belfast  Northern Ireland  £40,000 - £50,000 a year
# 13     County Tyrone  Northern Ireland  £21,000 - £23,000 a year
# 14           Belfast  Northern Ireland  £40,000 - £50,000 a year
# 15           Belfast  Northern Ireland  £40,000 - £50,000 a year
# 16               NaN             Wales                £500 a day
# 17               NaN             Wales                £500 a day
# 18       Bangor LL57             Wales  £50,132 - £58,089 a year
# 19           Cardiff             Wales  £27,000 - £33,000 a year
# 20    Pontyclun CF72             Wales  £21,089 - £23,761 a year
# 21         Pontyclun             Wales  £21,089 - £23,761 a year
# 22      Cwmbran NP44             Wales  £32,316 - £37,985 a year
# 23           Cardiff             Wales  £33,797 - £40,322 a year
# 24     Monmouthshire             Wales  £37,570 - £43,772 a year
# 25           Newport             Wales  £30,000 - £35,000 a year
# 26           Swansea             Wales  £50,000 - £60,000 a year
# 27           Cardiff             Wales         £130 - £170 a day
# 28               NaN             Wales            £21,000 a year
# 29               NaN             Wales  £19,000 - £20,000 a year
# ...              ...               ...                       ...
# 1898             NaN           England  £35,000 - £45,000 a year
# 1899             NaN           England  £20,000 - £28,000 a year
# 1900             NaN           England  £39,772 - £42,683 a year
# 1901             NaN           England               £11 an hour
# 1938             NaN           England  £35,000 - £45,000 a year
# 1939             NaN           England  £20,000 - £28,000 a year
# 1940             NaN           England  £39,772 - £42,683 a year
# 1941             NaN           England               £11 an hour
# 1978             NaN           England  £35,000 - £45,000 a year
# 1979             NaN           England  £20,000 - £28,000 a year
# 1980             NaN           England  £39,772 - £42,683 a year
# 1981             NaN           England               £11 an hour
# 2018             NaN           England  £35,000 - £45,000 a year
# 2019             NaN           England  £20,000 - £28,000 a year
# 2020             NaN           England  £39,772 - £42,683 a year
# 2021             NaN           England               £11 an hour
# 2058             NaN           England  £35,000 - £45,000 a year
# 2059             NaN           England  £20,000 - £28,000 a year
# 2060             NaN           England  £39,772 - £42,683 a year
# 2061             NaN           England               £11 an hour
# 2098             NaN           England  £35,000 - £45,000 a year
# 2099             NaN           England  £20,000 - £28,000 a year
# 2100             NaN           England  £39,772 - £42,683 a year
# 2101             NaN           England               £11 an hour
# 2138             NaN           England  £35,000 - £45,000 a year
# 2139             NaN           England  £20,000 - £28,000 a year
# 2140             NaN           England  £39,772 - £42,683 a year
# 2141             NaN           England               £11 an hour
# 2178             NaN           England  £35,000 - £45,000 a year
# 2179             NaN           England  £20,000 - £28,000 a year
#
#                                                    link  \
# 0     https://www.indeed.co.uk//rc/clk?jk=3222e19600...
# 1     https://www.indeed.co.uk//rc/clk?jk=94ecff3e9a...
# 2     https://www.indeed.co.uk//rc/clk?jk=c427cdddf4...
# 3     https://www.indeed.co.uk//rc/clk?jk=96d01bffcf...
# 4     https://www.indeed.co.uk//rc/clk?jk=bfe04ead4e...
# 5     https://www.indeed.co.uk//rc/clk?jk=8cc3745452...
# 6     https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 7     https://www.indeed.co.uk//rc/clk?jk=b9ff91ca57...
# 8     https://www.indeed.co.uk//rc/clk?jk=186557480e...
# 9     https://www.indeed.co.uk//rc/clk?jk=4f87e38910...
# 10    https://www.indeed.co.uk//rc/clk?jk=4c7dd636b8...
# 11    https://www.indeed.co.uk//rc/clk?jk=3c17d319d3...
# 12    https://www.indeed.co.uk//rc/clk?jk=c86d7be2f7...
# 13    https://www.indeed.co.uk//rc/clk?jk=fed5755d1b...
# 14    https://www.indeed.co.uk//rc/clk?jk=6910f045e3...
# 15    https://www.indeed.co.uk//rc/clk?jk=fdc3b8c63a...
# 16    https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 17    https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 18    https://www.indeed.co.uk//rc/clk?jk=da2b44b460...
# 19    https://www.indeed.co.uk//company/MARKETMATE/j...
# 20    https://www.indeed.co.uk//rc/clk?jk=18cd1fca6c...
# 21    https://www.indeed.co.uk//rc/clk?jk=db7f25f88c...
# 22    https://www.indeed.co.uk//rc/clk?jk=cdaef2f90d...
# 23    https://www.indeed.co.uk//rc/clk?jk=e2406bc406...
# 24    https://www.indeed.co.uk//rc/clk?jk=6a567010b0...
# 25    https://www.indeed.co.uk//rc/clk?jk=0988fb4c1b...
# 26    https://www.indeed.co.uk//company/We-Predict/j...
# 27    https://www.indeed.co.uk//rc/clk?jk=3c98fb260b...
# 28    https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 29    https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# ...                                                 ...
# 1898  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1899  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1900  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1901  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1938  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1939  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1940  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1941  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1978  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1979  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1980  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 1981  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2018  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2019  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2020  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2021  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2058  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2059  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2060  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2061  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2098  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2099  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2100  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2101  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2138  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2139  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2140  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2141  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2178  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
# 2179  https://www.indeed.co.uk//pagead/clk?mo=r&ad=-...
#
#                                                 summary
# 0     Applications are invited for the above permane...
# 1     Introduction\nSoftware Test Engineer – AI Mach...
# 2     My client are literally one of the most succes...
# 3     Business Intelligence Analyst/Engineer (Omagh ...
# 4     Full Time\nPermanent\nDuties and responsibilit...
# 5     Full Time\nPermanent\nBusiness Intelligence An...
# 6     Duties and responsibilities\nGather report/pro...
# 7     Data Science Manager -Java / Python / R / C++/...
# 8     Data Scientist (Contract, Belfast)\n\nMy clien...
# 9     Data Science Manager -Java / Python / R / C++/...
# 10    VANRATH are proud to be working exclusively wi...
# 11    Working for one of Tyrone’s most prestigious e...
# 12    What you’ll do:\n– Execute quantitative analys...
# 13    Our client is looking to hire a permanent Juni...
# 14    What you’ll do:\n– Execute quantitative analys...
# 15    What you’ll do:\n– Execute quantitative analys...
# 16    Role Summary: This is an exciting opportunity ...
# 17    Role Summary:\n\nThis company is looking for a...
# 18    Applications are invited for the above permane...
# 19    MarketMate (www.marketmate.ai) is an AI startu...
# 20    An exciting opportunity has arisen for a highl...
# 21    Thank you for your interest in working for the...
# 22    Are you an experienced Business Intelligence M...
# 23    Business Intelligence Officer\n\nA secondment ...
# 24    We have an exciting opportunity in a Business ...
# 25    Are you someone who loves to work with Data an...
# 26    We Predict use predictive analytics to help co...
# 27    My client are government body based in Cardiff...
# 28    Stock/ Data Analyst The Trade Centre Wales are...
# 29    Job Summary:\nWorking within the Data Services...
# ...                                                 ...
# 1898  Job title: Data Analyst – with experience in N...
# 1899  DBS Data is currently looking for a SQL Data A...
# 1900  Data Analyst - £39,772 – £42,683 per annum We ...
# 1901  The succesfull candidate will exhibit the foll...
# 1938  Job title: Data Analyst – with experience in N...
# 1939  DBS Data is currently looking for a SQL Data A...
# 1940  Data Analyst - £39,772 – £42,683 per annum We ...
# 1941  The succesfull candidate will exhibit the foll...
# 1978  Job title: Data Analyst – with experience in N...
# 1979  DBS Data is currently looking for a SQL Data A...
# 1980  Data Analyst - £39,772 – £42,683 per annum We ...
# 1981  The succesfull candidate will exhibit the foll...
# 2018  Job title: Data Analyst – with experience in N...
# 2019  DBS Data is currently looking for a SQL Data A...
# 2020  Data Analyst - £39,772 – £42,683 per annum We ...
# 2021  The succesfull candidate will exhibit the foll...
# 2058  Job title: Data Analyst – with experience in N...
# 2059  DBS Data is currently looking for a SQL Data A...
# 2060  Data Analyst - £39,772 – £42,683 per annum We ...
# 2061  The succesfull candidate will exhibit the foll...
# 2098  Job title: Data Analyst – with experience in N...
# 2099  DBS Data is currently looking for a SQL Data A...
# 2100  Data Analyst - £39,772 – £42,683 per annum We ...
# 2101  The succesfull candidate will exhibit the foll...
# 2138  Job title: Data Analyst – with experience in N...
# 2139  DBS Data is currently looking for a SQL Data A...
# 2140  Data Analyst - £39,772 – £42,683 per annum We ...
# 2141  The succesfull candidate will exhibit the foll...
# 2178  Job title: Data Analyst – with experience in N...
# 2179  DBS Data is currently looking for a SQL Data A...
#
# [1715 rows x 8 columns]
