# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Load-in-the-the-data-of-scraped-salaries" data-toc-modified-id="Load-in-the-the-data-of-scraped-salaries-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Load in the the data of scraped salaries</a></span></li><li><span><a href="#We-want-to-predict-a-binary-variable---whether-the-salary-was-low-or-high.-Compute-the-median-salary-and-create-a-new-binary-variable-that-is-true-when-the-salary-is-high-(above-the-median)." data-toc-modified-id="We-want-to-predict-a-binary-variable---whether-the-salary-was-low-or-high.-Compute-the-median-salary-and-create-a-new-binary-variable-that-is-true-when-the-salary-is-high-(above-the-median).-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median).</a></span><ul class="toc-item"><li><span><a href="#Thought-experiment:-What-is-the-baseline-accuracy-for-this-model?" data-toc-modified-id="Thought-experiment:-What-is-the-baseline-accuracy-for-this-model?-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Thought experiment: What is the baseline accuracy for this model?</a></span></li></ul></li><li><span><a href="#Create-a-classification-model-to-predict-High/Low-salary." data-toc-modified-id="Create-a-classification-model-to-predict-High/Low-salary.-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Create a classification model to predict High/Low salary.</a></span><ul class="toc-item"><li><span><a href="#Class-for-Preprocessing-of-data-of-existing-features" data-toc-modified-id="Class-for-Preprocessing-of-data-of-existing-features-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Class for Preprocessing of data of existing features</a></span></li><li><span><a href="#Single-Feature-Selection,-OneHotEncoding-and-Scaling" data-toc-modified-id="Single-Feature-Selection,-OneHotEncoding-and-Scaling-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Single Feature Selection, OneHotEncoding and Scaling</a></span></li><li><span><a href="#Model-Selection-and-initial-scoring-(Logistic-regression-&amp;-Decision-Tree-Classifier)" data-toc-modified-id="Model-Selection-and-initial-scoring-(Logistic-regression-&amp;-Decision-Tree-Classifier)-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Model Selection and initial scoring (Logistic regression &amp; Decision Tree Classifier)</a></span><ul class="toc-item"><li><span><a href="#Logistic-Regression-Model" data-toc-modified-id="Logistic-Regression-Model-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Logistic Regression Model</a></span></li><li><span><a href="#Short-summary-on-Coefficients" data-toc-modified-id="Short-summary-on-Coefficients-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Short summary on Coefficients</a></span></li><li><span><a href="#DecisionTree-Classifier-Model" data-toc-modified-id="DecisionTree-Classifier-Model-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>DecisionTree Classifier Model</a></span></li><li><span><a href="#Short-summary-on-Feature-Importance" data-toc-modified-id="Short-summary-on-Feature-Importance-3.3.4"><span class="toc-item-num">3.3.4&nbsp;&nbsp;</span>Short summary on Feature Importance</a></span></li></ul></li><li><span><a href="#Class-for-Preprocessing-of-textual-data-from-job-descriptions" data-toc-modified-id="Class-for-Preprocessing-of-textual-data-from-job-descriptions-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Class for Preprocessing of textual data from job descriptions</a></span><ul class="toc-item"><li><span><a href="#Mulitple-Feature-Selection-(Job-Category,-Region,-Job-Level-+-Top-500-words-from-Tfidf-processing-of-summary)" data-toc-modified-id="Mulitple-Feature-Selection-(Job-Category,-Region,-Job-Level-+-Top-500-words-from-Tfidf-processing-of-summary)-3.4.1"><span class="toc-item-num">3.4.1&nbsp;&nbsp;</span>Mulitple Feature Selection (Job Category, Region, Job Level + Top 500 words from Tfidf processing of summary)</a></span></li><li><span><a href="#Logistic-Regression-Model-with-multiple-features" data-toc-modified-id="Logistic-Regression-Model-with-multiple-features-3.4.2"><span class="toc-item-num">3.4.2&nbsp;&nbsp;</span>Logistic Regression Model with multiple features</a></span></li><li><span><a href="#Decision-Tree-Model-with-multiple-features" data-toc-modified-id="Decision-Tree-Model-with-multiple-features-3.4.3"><span class="toc-item-num">3.4.3&nbsp;&nbsp;</span>Decision Tree Model with multiple features</a></span></li></ul></li><li><span><a href="#GridSearch-tuning-of-Logistic-Regression-Model" data-toc-modified-id="GridSearch-tuning-of-Logistic-Regression-Model-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>GridSearch tuning of Logistic Regression Model</a></span><ul class="toc-item"><li><span><a href="#Final-Logistic-Regression-Model-Coefficients" data-toc-modified-id="Final-Logistic-Regression-Model-Coefficients-3.5.1"><span class="toc-item-num">3.5.1&nbsp;&nbsp;</span>Final Logistic Regression Model Coefficients</a></span></li></ul></li><li><span><a href="#GridSearch-tuning-of-Decision-Tree-Model" data-toc-modified-id="GridSearch-tuning-of-Decision-Tree-Model-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>GridSearch tuning of Decision Tree Model</a></span><ul class="toc-item"><li><span><a href="#Final-Decision-Tree-Model-Feature-Importance" data-toc-modified-id="Final-Decision-Tree-Model-Feature-Importance-3.6.1"><span class="toc-item-num">3.6.1&nbsp;&nbsp;</span>Final Decision Tree Model Feature Importance</a></span></li></ul></li></ul></li><li><span><a href="#Model-evaluation:" data-toc-modified-id="Model-evaluation:-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Model evaluation:</a></span><ul class="toc-item"><li><span><a href="#Cross-Validation-for-Tuned-Logistic-Regression-Model" data-toc-modified-id="Cross-Validation-for-Tuned-Logistic-Regression-Model-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Cross-Validation for Tuned Logistic Regression Model</a></span></li><li><span><a href="#Accuracy,-Area-under-the-curve,-Precision-and-Recall-scores" data-toc-modified-id="Accuracy,-Area-under-the-curve,-Precision-and-Recall-scores-4.2"><span class="toc-item-num">4.2&nbsp;&nbsp;</span>Accuracy, Area under the curve, Precision and Recall scores</a></span></li><li><span><a href="#ROC-Curve" data-toc-modified-id="ROC-Curve-4.3"><span class="toc-item-num">4.3&nbsp;&nbsp;</span>ROC Curve</a></span></li><li><span><a href="#Precision-Recall-Curve" data-toc-modified-id="Precision-Recall-Curve-4.4"><span class="toc-item-num">4.4&nbsp;&nbsp;</span>Precision-Recall Curve</a></span></li><li><span><a href="#Boss's-request" data-toc-modified-id="Boss's-request-4.5"><span class="toc-item-num">4.5&nbsp;&nbsp;</span>Boss's request</a></span></li></ul></li><li><span><a href="#Bonus:" data-toc-modified-id="Bonus:-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Bonus:</a></span><ul class="toc-item"><li><span><a href="#Salary-Discussion" data-toc-modified-id="Salary-Discussion-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Salary Discussion</a></span></li><li><span><a href="#High-Precision-or-High-Recall?" data-toc-modified-id="High-Precision-or-High-Recall?-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>High Precision or High Recall?</a></span><ul class="toc-item"><li><span><a href="#When-do-you-want-a-high-precision-model?" data-toc-modified-id="When-do-you-want-a-high-precision-model?-5.2.1"><span class="toc-item-num">5.2.1&nbsp;&nbsp;</span>When do you want a high precision model?</a></span></li><li><span><a href="#When-do-you-want-a-high-recall-model?" data-toc-modified-id="When-do-you-want-a-high-recall-model?-5.2.2"><span class="toc-item-num">5.2.2&nbsp;&nbsp;</span>When do you want a high recall model?</a></span></li></ul></li><li><span><a href="#Cross-Validation-for-Tuned-Decision-Tree-Model" data-toc-modified-id="Cross-Validation-for-Tuned-Decision-Tree-Model-5.3"><span class="toc-item-num">5.3&nbsp;&nbsp;</span>Cross-Validation for Tuned Decision Tree Model</a></span></li><li><span><a href="#Accuracy,-Area-under-the-curve,-Precision-and-Recall-scores" data-toc-modified-id="Accuracy,-Area-under-the-curve,-Precision-and-Recall-scores-5.4"><span class="toc-item-num">5.4&nbsp;&nbsp;</span>Accuracy, Area under the curve, Precision and Recall scores</a></span></li><li><span><a href="#Comparison-of-Logistic-Regression-and-Decision-Tree-ROC-&amp;-Precision-Recall-Curve" data-toc-modified-id="Comparison-of-Logistic-Regression-and-Decision-Tree-ROC-&amp;-Precision-Recall-Curve-5.5"><span class="toc-item-num">5.5&nbsp;&nbsp;</span>Comparison of Logistic Regression and Decision Tree ROC &amp; Precision-Recall Curve</a></span></li><li><span><a href="#Precision-Recall-Curve" data-toc-modified-id="Precision-Recall-Curve-5.6"><span class="toc-item-num">5.6&nbsp;&nbsp;</span>Precision-Recall Curve</a></span></li></ul></li><li><span><a href="#Summarize-your-results-in-an-executive-summary-written-for-a-non-technical-audience." data-toc-modified-id="Summarize-your-results-in-an-executive-summary-written-for-a-non-technical-audience.-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Summarize your results in an executive summary written for a non-technical audience.</a></span><ul class="toc-item"><li><span><a href="#Background" data-toc-modified-id="Background-6.1"><span class="toc-item-num">6.1&nbsp;&nbsp;</span>Background</a></span></li><li><span><a href="#Approach" data-toc-modified-id="Approach-6.2"><span class="toc-item-num">6.2&nbsp;&nbsp;</span>Approach</a></span><ul class="toc-item"><li><span><a href="#Target-Variable" data-toc-modified-id="Target-Variable-6.2.1"><span class="toc-item-num">6.2.1&nbsp;&nbsp;</span>Target Variable</a></span></li><li><span><a href="#Predictor-Variables" data-toc-modified-id="Predictor-Variables-6.2.2"><span class="toc-item-num">6.2.2&nbsp;&nbsp;</span>Predictor Variables</a></span></li></ul></li><li><span><a href="#Results" data-toc-modified-id="Results-6.3"><span class="toc-item-num">6.3&nbsp;&nbsp;</span>Results</a></span><ul class="toc-item"><li><span><a href="#Initial-Predictions" data-toc-modified-id="Initial-Predictions-6.3.1"><span class="toc-item-num">6.3.1&nbsp;&nbsp;</span>Initial Predictions</a></span></li><li><span><a href="#Tuning-of-Models" data-toc-modified-id="Tuning-of-Models-6.3.2"><span class="toc-item-num">6.3.2&nbsp;&nbsp;</span>Tuning of Models</a></span></li><li><span><a href="#Factors-which-determined-high-salary-jobs" data-toc-modified-id="Factors-which-determined-high-salary-jobs-6.3.3"><span class="toc-item-num">6.3.3&nbsp;&nbsp;</span>Factors which determined high salary jobs</a></span></li><li><span><a href="#Model-Precision" data-toc-modified-id="Model-Precision-6.3.4"><span class="toc-item-num">6.3.4&nbsp;&nbsp;</span>Model Precision</a></span></li></ul></li><li><span><a href="#Risks-and-Limitations" data-toc-modified-id="Risks-and-Limitations-6.4"><span class="toc-item-num">6.4&nbsp;&nbsp;</span>Risks and Limitations</a></span><ul class="toc-item"><li><span><a href="#The-Data" data-toc-modified-id="The-Data-6.4.1"><span class="toc-item-num">6.4.1&nbsp;&nbsp;</span>The Data</a></span></li><li><span><a href="#Data-Processing" data-toc-modified-id="Data-Processing-6.4.2"><span class="toc-item-num">6.4.2&nbsp;&nbsp;</span>Data Processing</a></span></li><li><span><a href="#Model-Selection" data-toc-modified-id="Model-Selection-6.4.3"><span class="toc-item-num">6.4.3&nbsp;&nbsp;</span>Model Selection</a></span></li></ul></li></ul></li><li><span><a href="#BONUS" data-toc-modified-id="BONUS-7"><span class="toc-item-num">7&nbsp;&nbsp;</span>BONUS</a></span></li></ul></div>

# %% [markdown]
# ### Load in the the data of scraped salaries

# %%
#Loading all necessary packages for assignment
#Numerical computation
import numpy as np

#Statistical computation
import scipy.stats as stats

#Visualisation
import seaborn as sns
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap

import scikitplot as skplt

from ipywidgets import *
from IPython.display import display
from IPython.display import Image

from shapely.geometry.polygon import LinearRing, Polygon
from descartes import PolygonPatch

from sklearn.externals.six import StringIO
from sklearn.tree import export_graphviz
import pydotplus


#Warnings suppression
import warnings
from sklearn.exceptions import DataConversionWarning
warnings.filterwarnings(action='ignore', category=DataConversionWarning)

# Dataframe management
import pandas as pd

#Parsing text
import re


#Modeling packages sklearn
from sklearn.preprocessing import StandardScaler,MinMaxScaler,PolynomialFeatures,OneHotEncoder,Binarizer, LabelBinarizer,OrdinalEncoder
from sklearn.linear_model import LinearRegression, RidgeCV,Ridge,LassoCV,Lasso,ElasticNetCV,ElasticNet,LogisticRegressionCV,LogisticRegression
from sklearn.model_selection import train_test_split,cross_val_score,KFold,cross_val_score,cross_val_predict,GridSearchCV
from sklearn.metrics import confusion_matrix,classification_report
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn.ensemble import RandomForestClassifier,RandomForestRegressor,AdaBoostClassifier,AdaBoostRegressor,GradientBoostingClassifier,GradientBoostingRegressor
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.svm import SVC

from sklearn.base import BaseEstimator, TransformerMixin

#packages for nlp
import nltk
from nltk.corpus import stopwords

#packages for pipelines
from sklearn.pipeline import Pipeline,FeatureUnion, make_pipeline,make_union




plt.style.use('ggplot')

# %config InlineBackend.figure_format = 'retina'
# %matplotlib inline

#Adjusting display to show all columns and rows
pd.set_option('display.max_columns',500)
pd.set_option('display.max_rows',2000)

# %%
#Pulling prepared data for classification problem
df = pd.read_csv("classification_data.csv")

# %% [markdown]
# ### We want to predict a binary variable - whether the salary was low or high. Compute the median salary and create a new binary variable that is true when the salary is high (above the median).
#
# We could also perform Linear Regression (or any regression) to predict the salary value here. Instead, we are going to convert this into a _binary_ classification problem, by predicting two classes, HIGH vs LOW salary.
#
# While performing regression may be better, performing classification may help remove some of the noise of the extreme salaries. We don't have to choose the `median` as the splitting point - we could also split on the 75th percentile or any other reasonable breaking point.
#
# In fact, the ideal scenario may be to predict many levels of salaries.

# %%
#Median salary is about £50,000
df.equivalent_salary.median()
# Out:
# 50000.0

# %%
#1st job in the dataframe is classified as 'high salary'
#2nd job in the dataframe is classified as 'low salary'
df.iloc[:2,[0,1,2,3,4,7,8,14,15]]
# Out:
#                                            job_title        job_category  \
# 0  Aerospace Engineer – Research Scientist (Dayto...  Research Scientist
# 1                    Research Scientist ($40-55k/yr)  Research Scientist
#
#            company      location region  \
# 0  Ahmic Aerospace           NaN   West
# 1        Expesicor  Missoula, MT   West
#
#                                              summary        country  \
# 0  About Us: Ahmic is a small aerospace research ...  United States
# 1  Please fill out a full application at expesico...  United States
#
#    equivalent_salary level
# 0       59454.313673   Mid
# 1       36676.362330   Mid

# %%
#Converting Target variable from continuous variable to categorical (1 = 'high salary', 0 = 'low salary') - split at the median salary
df['salary_class'] = df.equivalent_salary.apply(lambda x : 1 if x > df.equivalent_salary.median() else 0)
df = df.drop('equivalent_salary',axis=1)

# %%
df.iloc[1083:1084,[0,1,2,3,4,7,8,14,15]]
# Out:
#          job_title  job_category      company location region  \
# 1083  Data Analyst  Data Analyst  Aaratechinc      NaN   West
#
#                                                 summary        country level  \
# 1083  Required Skills: · Must have demonstrated test...  United States   Mid
#
#       salary_class
# 1083             0

# %%
#Conducting Train-test-splitting of data with stratification to preserve class and shuffling to ensure objectivity
# 20% testing, 80% training; Random state of zero will be used for consistency
from sklearn.model_selection import train_test_split

y = df.salary_class.values

X = df.drop('salary_class',axis=1)

#Train-test-splitting of data with stratification to preserve class
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0,stratify=y, shuffle=True)

# %% [markdown]
# #### Thought experiment: What is the baseline accuracy for this model?

# %% [markdown]
# >**Baseline accuracy will be about** `50%` **based on median salary split**

# %%
#Baseline accuracy expected (0.50) from the majority class
pd.Series(y).value_counts(normalize=True)
# Out:
# 0    0.501636
# 1    0.498364
# dtype: float64

# %% [markdown]
# ### Create a classification model to predict High/Low salary.
#
#
# - Start by ONLY using the location as a feature.
# - Use at least two different classifiers you find suitable.
# - Remember that scaling your features might be necessary.
# - Display the coefficients/feature importances and write a short summary of what they mean.
# - Create a few new variables in your dataframe to represent interesting features of a job title (e.g. whether 'Senior' or 'Manager' is in the title).
# - Incorporate other text features from the title or summary that you believe will predict the salary.
# - Then build new classification models including also those features. Do they add any value?
# - Tune your models by testing parameter ranges, regularization strengths, etc. Discuss how that affects your models.
# - Discuss model coefficients or feature importances as applicable.

# %% [markdown]
# #### Class for Preprocessing of data of existing features

# %%
from sklearn.base import BaseEstimator, TransformerMixin

#Creating custom preprocessor that will decide how many features to retain
class SalaryPreprocessor(BaseEstimator,TransformerMixin):
    
    def __init__(self,columns_to_drop = None):
        self.feature_names = []
        self.columns_to_drop = columns_to_drop
        
    def _drop_columns(self,X):
        X = X.drop(self.columns_to_drop,axis=1)
        return X
    
    def transform(self, X, *args):
        X = self._drop_columns(X)
        self.feature_names = X.columns
        return X
    
    def fit(self, X, *args):
        return self

# %% [markdown]
# #### Single Feature Selection, OneHotEncoding and Scaling

# %%
X_train_single = SalaryPreprocessor(columns_to_drop=['job_title', 'company', 'location', 'region', 'salary',
       'link', 'summary', 'country', 'exch_rate', 'pay_rate', 'lower', 'upper',
       'median_salary', 'level']).fit_transform(X_train)

X_test_single = SalaryPreprocessor(columns_to_drop=['job_title', 'company', 'location', 'region', 'salary',
       'link', 'summary', 'country', 'exch_rate', 'pay_rate', 'lower', 'upper',
       'median_salary', 'level']).fit_transform(X_test)

# %%
from sklearn.preprocessing import OneHotEncoder,StandardScaler,MinMaxScaler

#Conducting One Hot Encoding
encoder = OneHotEncoder(sparse=False,handle_unknown='ignore')
X_train_single = pd.DataFrame(encoder.fit_transform(X_train_single),columns=encoder.get_feature_names(),index=X_train_single.index).iloc[:,1:]
X_test_single = pd.DataFrame(encoder.transform(X_test_single),columns=encoder.get_feature_names(),index=X_test_single.index).iloc[:,1:]

# %%
#Conducting Scaling without mean
scaler =MinMaxScaler()

X_train_single = pd.DataFrame(scaler.fit_transform(X_train_single),columns=X_train_single.columns)
X_test_single = pd.DataFrame(scaler.transform(X_test_single),columns=X_test_single.columns)

# %% [markdown]
# #### Model Selection and initial scoring (Logistic regression & Decision Tree Classifier)

# %% [markdown]
# ##### Logistic Regression Model

# %%
#Instantiating logistic regression model
logr = LogisticRegression(solver='lbfgs',max_iter=10000,random_state=0)

# %%
logr.fit(X_train_single,y_train)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=10000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
cmap = ListedColormap(sns.color_palette("husl", len(logr.classes_)))
print(f"Training score:{logr.score(X_train_single,y_train):.3f}")
print(f"Testing score:{logr.score(X_test_single,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(logr,X_train_single,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(logr,X_train_single,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.668
# Testing score:0.673
# Cross Validation score:0.666
# Cross Validation variance:0.004

# %% [markdown]
# **Model Cross validation scores performs better than baseline**

# %%
y_pred_train = logr.predict(X_train_single)
y_pred_test = logr.predict(X_test_single)

def plot_confusion(y, y_pred,title="No Title"):
    skplt.metrics.plot_confusion_matrix(y, y_pred, labels=[1,0], figsize=(6,6),title=title)
    plt.ylim([-0.5, 1.5]);

# %%
plot_confusion(y_test,y_pred_test,"Confusion Matrix\n Logistic Regression Model")

# %%
#Creating DataFrame with coefficients with Absolute values
coef_df = pd.DataFrame(logr.coef_[0],index=X_train_single.columns,columns = ['coef'])
coef_df['coef_abs'] = coef_df.apply(abs)
coef_df['intercept'] = logr.intercept_[0]


sns.barplot(coef_df['coef'], coef_df.index );
coef_df.sort_values(by='coef_abs',ascending=False)
# Out:
#                            coef  coef_abs  intercept
# x0_Data Scientist      1.330616  1.330616  -0.147002
# x0_Machine Learning    1.002139  1.002139  -0.147002
# x0_Data Analyst       -0.569521  0.569521  -0.147002
# x0_Research Scientist  0.107244  0.107244  -0.147002

# %%
1/(1+np.exp(logr.intercept_[0]+logr.coef_[0][0]))
# Out:
# 0.6718409185017529

# %% [markdown]
# ##### Short summary on Coefficients
# > **Logistic Regression** coefficients represent the log of odds that the features (Data Analyst, Data Scientist, Machine Learning, Research Scientist, Business Intelligence) determines the particular class it is in:
#
# >A job ad with the title ``Data Scientist`` in it will have a +ve coefficient of **1.3214** : This means there is a roughly **0.234** probability of being in the majority class (i.e having a low salary relative to the median of all data)
#
# $$\frac{1}{1 + e^(-0.136177+1.321412)} = 0.234$$
#
# >A job ad with the title ``Data Analyst`` in it will have a -ve coefficient of **-0.5884** : This means there is a roughly **0.673** probability of being in the majority class (i.e having a low salary relative to the median of all data)
#
# $$\frac{1}{1 + e^(-0.136177-0.588431)} = 0.673$$

# %% [markdown]
# ##### DecisionTree Classifier Model

# %%
#Instantiating DecisionTree classifier with minimum samples for splitting of about 5% (122 samples)
dtree = DecisionTreeClassifier(random_state=0,min_samples_split=122)

dtree.fit(X_train_single,y_train)
# Out:
# DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
#             min_samples_leaf=1, min_samples_split=122,
#             min_weight_fraction_leaf=0.0, presort=False, random_state=0,
#             splitter='best')

# %%
print(f"Training score:{dtree.score(X_train_single,y_train):.3f}")
print(f"Testing score:{dtree.score(X_test_single,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(dtree,X_train_single,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(dtree,X_train_single,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.668
# Testing score:0.673
# Cross Validation score:0.666
# Cross Validation variance:0.004

# %% [markdown]
# **Model Cross validation scores performs better than baseline and similar to Logistic Regression**

# %%
y_pred_train = dtree.predict(X_train_single)
y_pred_test = dtree.predict(X_test_single)

plot_confusion(y_test,y_pred_test,"Confusion Matrix\n Decision Tree Classifier Model")

# %%
feat_df = pd.DataFrame(dtree.feature_importances_,index=X_train_single.columns,columns = ['feat'])
feat_df.sort_values(by='feat',ascending=False)
# Out:
#                            feat
# x0_Data Scientist      0.701835
# x0_Machine Learning    0.211086
# x0_Data Analyst        0.085453
# x0_Research Scientist  0.001626

# %%
dot_data = StringIO()
export_graphviz(dtree,
                out_file=dot_data,
                filled=True,
                rounded=True,
                special_characters=True,
                feature_names=X_test_single.columns,
                class_names=['Low Salary','High Salary'],
                max_depth=4,
                proportion=False
                )

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

Image(graph.create_png())

# %%
gini_gain_0 = 1*0.5 - 0.458*(1330/2444) - 0.439*(1114/2444)
gini_gain_1 = 0.458*(1330/2444) - 0.497*(705/2444) - 0.356*(625/2444)
gini_gain_2 = 0.497*705/2444 - 0.499*(520/2444) - 0.409*(185/2444)
gini_gain_3 = 0.499*(520/2444) - 0.497*(313/2444) - 0.5*(207/2444)

total_gain = gini_gain_0 + gini_gain_1 +gini_gain_2 +gini_gain_3

print(f'Research Analyst: {gini_gain_0/total_gain:.3f}')
print(f'Data Scientist: {gini_gain_1/total_gain:.3f}')
print(f'Machine Learning: {gini_gain_2/total_gain:.3f}')
print(f'Research Scientist: {gini_gain_3/total_gain:.3f}')
# Out:
# Research Analyst: 0.705
# Data Scientist: 0.206
# Machine Learning: 0.087
# Research Scientist: 0.002

# %% [markdown]
# ##### Short summary on Feature Importance
# > **Decision Tree** feature importance represents the contribution of a particular feature (Data Analyst, Data Scientist, Machine Learning, Research Scientist, Business Intelligence) in class segregation:
#
# > - A job ad with the title ``Data Analyst`` contributes **~70.5%** to the separation of high salary jobs from low salary jobs
# > - A job ad with the title ``Data Scientist`` contributes **~20.6%** to the separation of high salary jobs from low salary jobs
# > - A job ad with the title ``Machine Learning`` contributes **~8.7%** to the separation of high salary jobs from low salary jobs
# > - A job ad with the title ``Research Scientist`` contributes **~0.2%** to the separation of high salary jobs from low salary jobs
# > - A job ad with the title ``Business Intelligence`` **does not contribute** to the separation of high salary jobs from low salary jobs

# %% [markdown]
# #### Class for Preprocessing of textual data from job descriptions

# %%
#Creating text selector in preparation for the creation of any additional features using TfidfVectorization

class TextSelector(BaseEstimator,TransformerMixin):
    
    def __init__(self,columns_toproc=None):
        self.columns_toproc = columns_toproc
        self.feature_names = []
    
    def _to_str(self,X):
        try:
            Xcopy = X.copy()
            Xcopy.loc[:,self.columns_toproc] = X[self.columns_toproc].apply(str)#copyX = X.copy()
            X = Xcopy
            #X.loc[:,[self.columns_toproc]] = copyX[self.columns_toproc].apply(str).to_numpy()

        except:
            pass
        return X
    
    def fit(self,X,*args):
        return self
    
    def transform(self,X,*args):
        X = self._to_str(X)
        self.feature_names = X.columns
        return X.loc[:,self.columns_toproc]

# %% [markdown]
# ##### Mulitple Feature Selection (Job Category, Region, Job Level + Top 500 words from Tfidf processing of summary)

# %%
#Adding additional features (Job Category, Region, Job Level, country + Top 500 words from Tfidf processing of summary)

#Including job_category, region, level and country

X_train_s = SalaryPreprocessor(columns_to_drop=['job_title','company','location','salary',
                                    'link','summary','exch_rate','pay_rate','lower','upper','median_salary']).fit_transform(X_train)

X_test_s = SalaryPreprocessor(columns_to_drop=['job_title','company','location','salary',
                                    'link','summary','exch_rate','pay_rate','lower','upper','median_salary']).fit_transform(X_test)

X_s = SalaryPreprocessor(columns_to_drop=['job_title','company','location','salary',
                                    'link','summary','exch_rate','pay_rate','lower','upper','median_salary']).fit_transform(X)

X_train_s.head()
# Out:
#             job_category   region         country   level
# 2147      Data Scientist  England  United Kingdom  Senior
# 2676        Data Analyst  England  United Kingdom     Mid
# 1060        Data Analyst     West   United States     Mid
# 2468        Data Analyst  England  United Kingdom     Mid
# 1248  Research Scientist  England  United Kingdom     Mid

# %%
#OneHotEncoding on all categorical features chosen
X_train_s = pd.DataFrame(encoder.fit_transform(X_train_s),columns=encoder.get_feature_names(),index=X_train_s.index)
X_test_s = pd.DataFrame(encoder.transform(X_test_s),columns=encoder.get_feature_names(),index=X_test_s.index)
X_train_s.head()
# Out:
#       x0_Business Intelligence  x0_Data Analyst  x0_Data Scientist  \
# 2147                       0.0              0.0                1.0
# 2676                       0.0              1.0                0.0
# 1060                       0.0              1.0                0.0
# 2468                       0.0              1.0                0.0
# 1248                       0.0              0.0                0.0
#
#       x0_Machine Learning  x0_Research Scientist  x1_Alberta  \
# 2147                  0.0                    0.0         0.0
# 2676                  0.0                    0.0         0.0
# 1060                  0.0                    0.0         0.0
# 2468                  0.0                    0.0         0.0
# 1248                  0.0                    1.0         0.0
#
#       x1_British Columbia  x1_England  x1_Manitoba  x1_MidWest  \
# 2147                  0.0         1.0          0.0         0.0
# 2676                  0.0         1.0          0.0         0.0
# ...

# %%
scaler =MinMaxScaler()
X_train_s = pd.DataFrame(scaler.fit_transform(X_train_s),columns=X_train_s.columns,index=X_train_s.index)
X_test_s = pd.DataFrame(scaler.transform(X_test_s),columns=X_test_s.columns,index=X_test_s.index)
X_train_s.head()
# Out:
#       x0_Business Intelligence  x0_Data Analyst  x0_Data Scientist  \
# 2147                       0.0              0.0                1.0
# 2676                       0.0              1.0                0.0
# 1060                       0.0              1.0                0.0
# 2468                       0.0              1.0                0.0
# 1248                       0.0              0.0                0.0
#
#       x0_Machine Learning  x0_Research Scientist  x1_Alberta  \
# 2147                  0.0                    0.0         0.0
# 2676                  0.0                    0.0         0.0
# 1060                  0.0                    0.0         0.0
# 2468                  0.0                    0.0         0.0
# 1248                  0.0                    1.0         0.0
#
#       x1_British Columbia  x1_England  x1_Manitoba  x1_MidWest  \
# 2147                  0.0         1.0          0.0         0.0
# 2676                  0.0         1.0          0.0         0.0
# ...

# %%
#Selecting the summary column for textual processing
X_train_t = TextSelector('summary').fit_transform(X_train)
X_test_t = TextSelector('summary').fit_transform(X_test)
X_train_t.head()
# Out:
# 2147    Smartlytics Consultancy a small analytics cons...
# 2676    The Company\n\nA leading provider of research,...
# 1060    Position Summary/ Purpose\n\nUnder the directi...
# 2468    They promote and support progressive careers w...
# 1248    The Babraham Institute is a charity, which is ...
# Name: summary, dtype: object

# %%
#Creating a function to do custom tokenizers of string which are segmented and split
def Tokenizer(str_input):
    words = re.sub(r"[^A-Za-z0-9\-]", " ", str_input).lower().split()
    return words

#creating list of stopwords from english
stopwordz = stopwords.words('english')

#Creating tfidf vectorizer with a filter (filter very infrequent words - 0.0025; filter very frequent words - 0.9)
#Top 500 words that are important
tvec = TfidfVectorizer(tokenizer=Tokenizer, stop_words=list(set(stopwordz)),
                     min_df=.0025, max_df=0.9, max_features=500,ngram_range=(1,3))

# %%
#Vectorizing words in summary
X_train_t = pd.DataFrame(tvec.fit_transform(X_train_t).toarray(),columns= tvec.get_feature_names(),index=X_train_t.index)
X_test_t = pd.DataFrame(tvec.transform(X_test_t).toarray(),columns= tvec.get_feature_names(),index=X_test_t.index)
X_train_t.head()
# Out:
#              -   --        00  00 yearexperience       000    000 00  \
# 2147  0.082645  0.0  0.171991                0.0  0.307366  0.213331
# 2676  0.000000  0.0  0.000000                0.0  0.000000  0.000000
# 1060  0.024801  0.0  0.000000                0.0  0.046119  0.000000
# 2468  0.000000  0.0  0.000000                0.0  0.000000  0.000000
# 1248  0.000000  0.0  0.000000                0.0  0.049813  0.000000
#
#       000 00 yearexperience         1  1 year  1 year preferred         2  \
# 2147                    0.0  0.000000     0.0               0.0  0.000000
# 2676                    0.0  0.000000     0.0               0.0  0.000000
# 1060                    0.0  0.029487     0.0               0.0  0.060492
# 2468                    0.0  0.000000     0.0               0.0  0.000000
# 1248                    0.0  0.000000     0.0               0.0  0.065337
#
#        2 years      2019        3  3 years        30    4         5   5 years  \
# ...

# %%
#Concatenating all features and textual features
X_train_st = pd.concat([X_train_s,X_train_t],axis=1)
X_test_st = pd.concat([X_test_s,X_test_t],axis=1)

X_train_st.head()
# Out:
#       x0_Business Intelligence  x0_Data Analyst  x0_Data Scientist  \
# 2147                       0.0              0.0                1.0
# 2676                       0.0              1.0                0.0
# 1060                       0.0              1.0                0.0
# 2468                       0.0              1.0                0.0
# 1248                       0.0              0.0                0.0
#
#       x0_Machine Learning  x0_Research Scientist  x1_Alberta  \
# 2147                  0.0                    0.0         0.0
# 2676                  0.0                    0.0         0.0
# 1060                  0.0                    0.0         0.0
# 2468                  0.0                    0.0         0.0
# 1248                  0.0                    1.0         0.0
#
#       x1_British Columbia  x1_England  x1_Manitoba  x1_MidWest  \
# 2147                  0.0         1.0          0.0         0.0
# 2676                  0.0         1.0          0.0         0.0
# ...

# %% [markdown]
# ##### Logistic Regression Model with multiple features

# %%
#Logistic Regression with initial features only
logr = LogisticRegression(solver='lbfgs',max_iter=10000,random_state=0)

logr.fit(X_train_s,y_train)

print(f"Training score:{logr.score(X_train_s,y_train):.3f}")
print(f"Testing score:{logr.score(X_test_s,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(logr,X_train_s,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(logr,X_train_s,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.731
# Testing score:0.727
# Cross Validation score:0.712
# Cross Validation variance:0.020

# %%
#Logistic Regression with textual features only
logr.fit(X_train_t,y_train)

print(f"Training score:{logr.score(X_train_t,y_train):.3f}")
print(f"Testing score:{logr.score(X_test_t,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(logr,X_train_t,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(logr,X_train_t,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.872
# Testing score:0.822
# Cross Validation score:0.832
# Cross Validation variance:0.011

# %%
#Logistic Regression with combined features (initial and textual)
logr.fit(X_train_st,y_train)
         
print(f"Training score:{logr.score(X_train_st,y_train):.3f}")
print(f"Testing score:{logr.score(X_test_st,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(logr,X_train_st,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(logr,X_train_st,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.875
# Testing score:0.840
# Cross Validation score:0.828
# Cross Validation variance:0.018

# %% [markdown]
# >**Model has vastly improved in accuracy by the use of additional features and textual analysis**<br>
# - **Textual features have added the most value individually for the Logistic Regression**

# %%
y_pred_train = logr.predict(X_train_st)
y_pred_test = logr.predict(X_test_st)

plot_confusion(y_test,y_pred_test,"Confusion Matrix\n Logistic Regression Model with multiple features")

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.86      0.81      0.84       307
#            1       0.82      0.87      0.84       305
#
#    micro avg       0.84      0.84      0.84       612
#    macro avg       0.84      0.84      0.84       612
# weighted avg       0.84      0.84      0.84       612

# %% [markdown]
# ##### Decision Tree Model with multiple features

# %%
#Decision Tree with initial features only
dtree = DecisionTreeClassifier(random_state=0,min_samples_split=122)

dtree.fit(X_train_s,y_train)

print(f"Training score:{dtree.score(X_train_s,y_train):.3f}")
print(f"Testing score:{dtree.score(X_test_s,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(dtree,X_train_s,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(dtree,X_train_s,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.737
# Testing score:0.734
# Cross Validation score:0.726
# Cross Validation variance:0.019

# %%
#Decision Tree with textual features only
dtree.fit(X_train_t,y_train)

print(f"Training score:{dtree.score(X_train_t,y_train):.3f}")
print(f"Testing score:{dtree.score(X_test_t,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(dtree,X_train_t,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(dtree,X_train_t,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.860
# Testing score:0.740
# Cross Validation score:0.734
# Cross Validation variance:0.015

# %%
#Decision Tree with combined features (initial and textual)
dtree.fit(X_train_st,y_train)

print(f"Training score:{dtree.score(X_train_st,y_train):.3f}")
print(f"Testing score:{dtree.score(X_test_st,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(dtree,X_train_st,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(dtree,X_train_st,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.891
# Testing score:0.755
# Cross Validation score:0.761
# Cross Validation variance:0.014

# %% [markdown]
# >**Model has vastly improved in accuracy by the use of additional features and textual analysis**<br>
# - **Ordinary features have added the most value individually for the Decision Tree Classifier**

# %%
y_pred_train = dtree.predict(X_train_st)
y_pred_test = dtree.predict(X_test_st)

plot_confusion(y_test,y_pred_test,"Confusion Matrix\n Decision Tree Model with multiple features")

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.76      0.76      0.76       307
#            1       0.75      0.75      0.75       305
#
#    micro avg       0.75      0.75      0.75       612
#    macro avg       0.75      0.75      0.75       612
# weighted avg       0.75      0.75      0.75       612

# %% [markdown]
# #### GridSearch tuning of Logistic Regression Model

# %%
#Setting parameters for grid search
params_logr = {'C': np.logspace(0,2),
 'fit_intercept': [True,False],
 'penalty': ['l2','l1'],
 'solver': ['liblinear']}

# %%
grid_cv_logr = GridSearchCV(logr,param_grid=params_logr,n_jobs=-1,cv=5,verbose=2)

grid_cv_logr.fit(X_train_st,y_train)
# Out:
# Fitting 5 folds for each of 200 candidates, totalling 1000 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  58 tasks      | elapsed:    1.7s
# [Parallel(n_jobs=-1)]: Done 300 tasks      | elapsed:   12.2s
# [Parallel(n_jobs=-1)]: Done 582 tasks      | elapsed:   43.7s
# [Parallel(n_jobs=-1)]: Done 865 tasks      | elapsed:  1.6min
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:  2.1min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=10000, multi_class='warn',
#           n_jobs=None, penalty='l2', random_state=0, solver='lbfgs',
#           tol=0.0001, verbose=0, warm_start=False),
#        fit_params=None, iid='warn', n_jobs=-1,
#        param_grid={'C': array([  1.     ,   1.09854,   1.20679,   1.32571,   1.45635,   1.59986,
# ...

# %%
grid_cv_logr.best_score_
# Out:
# 0.8436988543371522

# %% [markdown]
# >**Model has marginally improved in accuracy after optimization of Logistic Regression model**<br>

# %%
grid_cv_logr.best_params_
# Out:
# {'C': 4.941713361323834,
#  'fit_intercept': True,
#  'penalty': 'l2',
#  'solver': 'liblinear'}

# %%
y_pred_train = grid_cv_logr.predict(X_train_st)
y_pred_test = grid_cv_logr.predict(X_test_st)

plot_confusion(y_test,y_pred_test,"Confusion Matrix\n Optimized Logistic Regression Model")

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       307
#            1       0.82      0.86      0.84       305
#
#    micro avg       0.83      0.83      0.83       612
#    macro avg       0.83      0.83      0.83       612
# weighted avg       0.83      0.83      0.83       612

# %% [markdown]
# ##### Final Logistic Regression Model Coefficients

# %%
logr.set_params(**grid_cv_logr.best_params_)
logr.fit(X_train_st,y_train)

#Creating DataFrame with coefficients with Absolute values
coef_df = pd.DataFrame(logr.coef_[0],index=X_train_st.columns,columns = ['coef'])
coef_df['coef_abs'] = coef_df.apply(abs)
coef_df['intercept'] = logr.intercept_[0]

# %%
normal_coef = coef_df.loc[X_train_s.columns,:].sort_values(by='coef_abs',ascending=False)
textual_coef = coef_df.loc[X_train_t.columns,:].sort_values(by='coef_abs',ascending=False)

# %% [markdown]
# **Chart of initial features and their coefficients**
#
# >1. The features ``Junior(job level)``, ``United Kingdom(job country)``, ``Scotland(job region)`` and ``Data Analyst(job category)`` all will have **high probabilities of being jobs with salaries below the median**<br>
# <br>
# >2. The features ``Principal(job level)``, ``Australia(job country)``, ``South Australia(job region)`` and ``Data Scientist(job category)`` all will have **low probabilities of being jobs with salaries below the median**<br>

# %%
plt.figure(figsize=(5,12))
sns.barplot(normal_coef['coef'], normal_coef.index );

# %%
normal_coef = coef_df.loc[X_train_s.columns,:].sort_values(by='coef',ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(normal_coef['coef'][:13], normal_coef.index[:13],palette='viridis_r',ec='k')
plt.xlabel("Factors that determine \nhigh salary data related job",fontsize=14,weight='bold')
plt.savefig("./images/logistic_coef.png");

# %% [markdown]
# **Chart of top 20 textual features and their coefficients**
#
# >3. The features ``description``, ``responsibilities``, ``marketing`` and ``2019`` that are included in the job summary indicate that the job will have a **high probability of offering a salary below the median**<br>
# <br>
# >4. The features ``products``, ``london``, ``contract`` and ``complex`` that are included in the job summary indicate that the job will have a **low probability of offering a salary below the median**<br>

# %%
textual_coef = coef_df.loc[X_train_t.columns,:].sort_values(by='coef',ascending=False)
plt.figure(figsize=(10,6))
sns.barplot(textual_coef['coef'][:13], textual_coef.index[:13],palette='viridis_r',ec='k')
plt.xlabel("Words in job description that\n determine high salary data related job",fontsize=14,weight='bold')
plt.savefig("./images/logistic_words.png");

# %%
plt.figure(figsize=(5,9))
sns.barplot(textual_coef['coef'][:20], textual_coef.index[:20]);

# %% [markdown]
# #### GridSearch tuning of Decision Tree Model

# %%
#Setting parameters for grid search
params_dtree= {'class_weight': [None],
 'criterion': ['gini','entropy'],
 'max_depth': list(range(2,20)),
 'max_features': list(range(2,10))+[None],
 'max_leaf_nodes': list(range(2,10))+[None]}

# %%
grid_cv_dtree = GridSearchCV(dtree,param_grid=params_dtree,n_jobs=-1,cv=5,verbose=2)

grid_cv_dtree.fit(X_train_st,y_train)
# Out:
# Fitting 5 folds for each of 2916 candidates, totalling 14580 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 4 concurrent workers.
# [Parallel(n_jobs=-1)]: Done 158 tasks      | elapsed:    1.4s
# [Parallel(n_jobs=-1)]: Done 884 tasks      | elapsed:    8.2s
# [Parallel(n_jobs=-1)]: Done 2102 tasks      | elapsed:   19.9s
# [Parallel(n_jobs=-1)]: Done 3800 tasks      | elapsed:   36.7s
# [Parallel(n_jobs=-1)]: Done 5990 tasks      | elapsed:   59.3s
# [Parallel(n_jobs=-1)]: Done 8660 tasks      | elapsed:  1.5min
# [Parallel(n_jobs=-1)]: Done 11822 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=-1)]: Done 14580 out of 14580 | elapsed:  2.8min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#        estimator=DecisionTreeClassifier(class_weight=None, criterion='gini', max_depth=None,
#             max_features=None, max_leaf_nodes=None,
#             min_impurity_decrease=0.0, min_impurity_split=None,
# ...

# %%
grid_cv_dtree.best_score_
# Out:
# 0.7749590834697218

# %% [markdown]
# >**Model has marginally improved in accuracy after optimization of Decision Tree model**<br>

# %%
grid_cv_dtree.best_params_
# Out:
# {'class_weight': None,
#  'criterion': 'gini',
#  'max_depth': 7,
#  'max_features': None,
#  'max_leaf_nodes': None}

# %%
y_pred_train = grid_cv_dtree.predict(X_train_st)
y_pred_test = grid_cv_dtree.predict(X_test_st)

plot_confusion(y_test,y_pred_test,"Confusion Matrix\n Optimized Decision Tree Model")

# %%
print(classification_report(y_test,y_pred_test))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       307
#            1       0.75      0.77      0.76       305
#
#    micro avg       0.76      0.76      0.76       612
#    macro avg       0.76      0.76      0.76       612
# weighted avg       0.76      0.76      0.76       612

# %% [markdown]
# ##### Final Decision Tree Model Feature Importance

# %%
dtree.set_params(**grid_cv_dtree.best_params_)
dtree.fit(X_train_st,y_train)

feat_df = pd.DataFrame(dtree.feature_importances_,index=X_train_st.columns,columns = ['feat'])
feat_df.sort_values(by='feat',ascending=False)[:30]
# Out:
#                        feat
# machine            0.237352
# x2_United Kingdom  0.152094
# london             0.068814
# 5 years            0.066945
# uk                 0.053601
# complex            0.040017
# experience         0.039816
# communication      0.036542
# x0_Data Analyst    0.031768
# responsibilities   0.029474
# 2019               0.025067
# various            0.023708
# client             0.023051
# requires           0.019759
# x3_Junior          0.017970
# analytics          0.017762
# production         0.016970
# cv                 0.015438
# large              0.015222
# individuals        0.011925
# analysis           0.010638
# life               0.010557
# insight            0.010410
# equal              0.009475
# quality            0.009063
# check              0.006560
# looking            0.000000
# plans              0.000000
# predictive         0.000000
# practices          0.000000

# %% [markdown]
# **Important features for the Decision Tree**
#
# A job ad that....
# > - has the word ``machine`` in its job description contributes **~20%** to the separation of high salary jobs from low salary jobs
# > - comes from the ``United Kingdom`` contributes **~12.2%** to the separation of high salary jobs from low salary jobs
# > - has the word ``5 years`` in its job description contributes **~6%** to the separation of high salary jobs from low salary jobs
# > - has the word ``london`` in its job description contributes **~5.2%** to the separation of high salary jobs from low salary jobs
# > - has the word ``complex`` in its job description contributes **~3.2%** to the separation of high salary jobs from low salary jobs
# > - has ``Data Analyst`` in its job title contributes **~2.3%** to the separation of high salary jobs from low salary jobs
# > - has ``Senior`` in its job title contributes **~1.5%** to the separation of high salary jobs from low salary jobs

# %%
dot_data = StringIO()
export_graphviz(dtree,
                out_file=dot_data,
                filled=True,
                rounded=True,
                special_characters=True,
                feature_names=X_test_st.columns,
                class_names=['Low Salary','High Salary'],
                max_depth=3,
                proportion=False
                )

graph = pydotplus.graph_from_dot_data(dot_data.getvalue())

graph.write_png("./images/decision_tree.png")
Image(graph.create_png())

# %% [markdown]
# ### Model evaluation:
#
# Your boss would rather tell a client incorrectly that they would get a lower salary job than tell a client incorrectly that they would get a high salary job. Adjust one of your models to ease his mind, and explain what it is doing and any tradeoffs.
#
#
# - Use cross-validation to evaluate your models.
# - Evaluate the accuracy, AUC, precision and recall of the models.
# - Plot the ROC and precision-recall curves for at least one of your models.

# %% [markdown]
# #### Cross-Validation for Tuned Logistic Regression Model

# %%
#Choosing Logistic Regression as the model to adjust based on its better cross validation score

#Setting best parameters for the model from GridSearch
logr.set_params(**grid_cv_logr.best_params_)
logr.fit(X_train_st,y_train)

y_pred_train = logr.predict(X_train_st)
y_pred_test = logr.predict(X_test_st)

#Printing cross validation scores and variance
print(f"Training score:{logr.score(X_train_st,y_train):.3f}")
print(f"Testing score:{logr.score(X_test_st,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(logr,X_train_st,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(logr,X_train_st,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.906
# Testing score:0.833
# Cross Validation score:0.844
# Cross Validation variance:0.010

# %% [markdown]
# >Model has relatively good cross validation scores compared to the baseline of 0.5

# %% [markdown]
# #### Accuracy, Area under the curve, Precision and Recall scores

# %%
from sklearn.metrics import accuracy_score,auc,precision_score,recall_score,roc_curve,precision_recall_curve,average_precision_score

#Calculating models accuracy
print(f"Accuracy score: {accuracy_score(y_test,y_pred_test):.3f}")

#Calculating model probabilities on test data
prob_test = pd.DataFrame(logr.predict_proba(X_test_st),columns=['class_0','class_1'],index = X_test.index)

#Extracting False Positive and True Positive rates for ROC curve plotting
fpr, tpr, threshold = roc_curve(y_test, prob_test.class_1)

#Calculating area under the curve
roc_auc = auc(fpr, tpr)
print(f"Area under curve (AUC): {roc_auc:.3f}")

#Showing precision and recall from classification report
print(classification_report(y_test,y_pred_test))
# Out:
# Accuracy score: 0.833
# Area under curve (AUC): 0.922
#               precision    recall  f1-score   support
#
#            0       0.85      0.81      0.83       307
#            1       0.82      0.86      0.84       305
#
#    micro avg       0.83      0.83      0.83       612
#    macro avg       0.83      0.83      0.83       612
# weighted avg       0.83      0.83      0.83       612

# %% [markdown]
# >Model has relatively good AUC and accuracy scores; Precision, recall and F-1 score is quite good

# %% [markdown]
# #### ROC Curve

# %%
#ROC curve for high salary prediction (class 1)
plt.figure(figsize=[6, 6])
plt.plot(fpr, tpr, label='ROC curve (area = %0.2f)' % roc_auc, linewidth=4,color='purple')
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([-0.05, 1.0])
plt.ylim([-0.05, 1.01])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC curve', fontsize=18)
plt.legend(loc="lower right");

# %% [markdown]
# >ROC curve shows that for a low False Positive Rate the model can give high degree of recall/high true positive rate

# %% [markdown]
# #### Precision-Recall Curve

# %%
#Extracting Precision and Recall values for curve plotting
precision, recall, threshold = precision_recall_curve(y_test, prob_test.class_1)

# Precision-recall curve for high salary prediction (class 1)
plt.figure(figsize=[6, 6])
plt.plot(recall, precision, label='Precision-recall curve', linewidth=4,color='g')
plt.xlim([-0.05, 1.01])
plt.ylim([-0.05, 1.01])
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.title('Precision-Recall curve', fontsize=18)
plt.legend(loc="lower right")
plt.show()

# %% [markdown]
# > Precision - Recall curve shows that for very low recall the model can be very precise; this falls off before 0.2 and slightly increases as the recall is near 0.4 after which it gradually declines in precision

# %% [markdown]
# #### Boss's request
#
# 1. Ideally my boss is searching for a model with very high ``precision`` when detecting high salary (class 1) jobs (i.e no false positives)<br>
# 2. He/she is willing to tell clients that the job has a low salary (class 0) even if it is likely to have a high salary (class 1) - he/she is willing to sacrifice the model's ``recall`` or allow more false negatives when detecting high salary jobs<br>
# 3. He/she is looking for a very low ``false positive rate`` as well
#
# **Essentially the model will need to be adjusted to have a high ``precision`` and low ``recall`` if necessary**<br>
# **In other words a low ``false positive rate`` is priority.**

# %%
#Defining function to adjust threshold
def adjust_threshold(x, threshold=0.5):
    if x >= threshold:
        return 1
    else:
        return 0

#Current comparison
prob_test['true_score'] = y_test
prob_test['predicted'] = prob_test.class_1.apply(adjust_threshold)
#prob_test.head(20)

#Showing some cases that my boss will like to avoid
prob_test[(prob_test['true_score'] == 0)&(prob_test['predicted'] == 1)].head(10)
# Out:
#        class_0   class_1  true_score  predicted
# 186   0.303373  0.696627           0          1
# 820   0.336745  0.663255           0          1
# 2167  0.169655  0.830345           0          1
# 638   0.450821  0.549179           0          1
# 2969  0.126854  0.873146           0          1
# 1681  0.068587  0.931413           0          1
# 1281  0.499624  0.500376           0          1
# 835   0.385046  0.614954           0          1
# 1560  0.341965  0.658035           0          1
# 2139  0.384635  0.615365           0          1

# %%
#Maximum threshold to use in order to ensure no low salary jobs are classified as high salary jobs
max_threshold = prob_test[(prob_test['true_score'] == 0)&(prob_test['predicted'] == 1)].class_1.max()
max_threshold
# Out:
# 0.9907106444666541

# %%
#Adjusting threshold to ensure no low salary jobs are classified as high salary jobs
prob_test['predicted'] = prob_test.class_1.apply(adjust_threshold,threshold=max_threshold+1e-16)

# %%
prob_test[(prob_test['true_score'] == 0)&(prob_test['predicted'] == 1)]
# Out:
# Empty DataFrame
# Columns: [class_0, class_1, true_score, predicted]
# Index: []

# %%
plot_confusion(y_test,prob_test['predicted'],"Confusion Matrix\n Adjusted Logistic Regression Model\n for 100% Precision")

# %%
#Calculating models new accuracy
print(f"Accuracy score: {accuracy_score(y_test,prob_test['predicted']):.3f}")

#Showing precision and recall from classification report
print(classification_report(y_test,prob_test['predicted']))
# Out:
# Accuracy score: 0.531
#               precision    recall  f1-score   support
#
#            0       0.52      1.00      0.68       307
#            1       1.00      0.06      0.11       305
#
#    micro avg       0.53      0.53      0.53       612
#    macro avg       0.76      0.53      0.40       612
# weighted avg       0.76      0.53      0.40       612

# %%
#Adjusting threshold to ensure of that at least 90% precision for jobs classified as high salary 
prob_test['predicted'] = prob_test.class_1.apply(adjust_threshold,threshold=0.75)

prob_test[(prob_test['true_score'] == 0)&(prob_test['predicted'] == 1)]

plot_confusion(y_test,prob_test['predicted'],"Confusion Matrix\n Adjusted Logistic Regression Model\n for 95% Precision")

# %%
#Calculating models new accuracy
print(f"Accuracy score: {accuracy_score(y_test,prob_test['predicted']):.3f}")

#Showing precision and recall from classification report
print(classification_report(y_test,prob_test['predicted']))
# Out:
# Accuracy score: 0.817
#               precision    recall  f1-score   support
#
#            0       0.76      0.93      0.84       307
#            1       0.90      0.71      0.79       305
#
#    micro avg       0.82      0.82      0.82       612
#    macro avg       0.83      0.82      0.81       612
# weighted avg       0.83      0.82      0.81       612

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### Bonus:
#
# - Answer the salary discussion by using your model to explain the tradeoffs between detecting high vs low salary positions.
# - Discuss the differences and explain when you want a high-recall or a high-precision model in this scenario.
# - Obtain the ROC/precision-recall curves for the different models you studied (at least the tuned model of each category) and compare.

# %%
## YOUR CODE HERE
acc = []; prec = []; thres = []; recal = []
for x in np.linspace(0,0.99,100):
    adj_thres = prob_test.class_1.apply(adjust_threshold,threshold=x)
    acc.append(accuracy_score(y_test,adj_thres))
    prec.append(precision_score(y_test,adj_thres))
    thres.append(x)
    recal.append(recall_score(y_test,adj_thres))
    
plt.figure(figsize=(8,6))
plt.plot(thres,acc,label="accuracy score",lw=5)
plt.plot(thres,prec,label="precision score")
plt.plot(thres,recal,label="recall score")
plt.xlabel("probability threshold for class 1 (high salary)", fontsize=16)
plt.ylabel("Score", fontsize=16)
plt.title("Accuracy,Precision or Recall vs. Probability threshold")

plt.legend();

# %% [markdown]
# #### Salary Discussion
#
# >While my boss can get **super precision (100% precision)** when identifying high salary jobs, the model can only identify **27 out of the 306** that exist in the landscape **(9% recall)**. As mentioned before he/she is willing to live with this level of recall.
#
# >Naturally this has an effect on the precision when identifying low salary jobs because **we will be telling most clients that jobs have low salaries** when only some have **(52% precision).** However this allows us to **identify all low paying jobs** in the landscape **(100% recall).**
#
# >Overall the **accuracy of the model will suffer** and this will decline towards the baseline of 50% (Which is like guessing the mean of all observations)
#
# >If my boss aims for **high precision (95% precision)** when identifying high salary jobs, the model will identify **152 out of the 306** that exist in the landscape **(59% recall)**. With this compromise we can still retain a 78% accuracy.

# %% [markdown]
# #### High Precision or High Recall?

# %% [markdown]
# ##### When do you want a high precision model?
#
# High precision model is required in a similar case as above, when the business is consulting exclusively for clients who want high salaries identified. They are looking to preserve the perception that "when we tell you its a high salary job... we mean it", and our performance is based on that. This model is required for high salary certainty in prediction.

# %% [markdown]
# ##### When do you want a high recall model?
# High recall model is required when we are surveying the job landscape to identify every possible high salary job. Your consultancy is based on finding all possible high salary jobs that exist in the market and letting you know the potential. The clients expectation is that you can tell me every potential high salary job in the marketplace with the disclaimer that some may turn out not to be so "high paying".

# %% [markdown]
# #### Cross-Validation for Tuned Decision Tree Model

# %%
#Setting best parameters for the model from GridSearch
dtree.set_params(**grid_cv_dtree.best_params_)
dtree.fit(X_train_st,y_train)

y_pred_train = dtree.predict(X_train_st)
y_pred_test = dtree.predict(X_test_st)

#Printing cross validation scores and variance
print(f"Training score:{dtree.score(X_train_st,y_train):.3f}")
print(f"Testing score:{dtree.score(X_test_st,y_test):.3f}")
print(f"Cross Validation score:{cross_val_score(dtree,X_train_st,y_train,cv=5,n_jobs=-1).mean():.3f}")
print(f"Cross Validation variance:{cross_val_score(dtree,X_train_st,y_train,cv=5,n_jobs=-1).std():.3f}")
# Out:
# Training score:0.827
# Testing score:0.760
# Cross Validation score:0.775
# Cross Validation variance:0.016

# %% [markdown]
# #### Accuracy, Area under the curve, Precision and Recall scores

# %%
#Calculating models accuracy
print(f"Accuracy score: {accuracy_score(y_test,y_pred_test):.3f}")

#Calculating model probabilities on test data
prob_test_dtree = pd.DataFrame(dtree.predict_proba(X_test_st),columns=['class_0','class_1'],index = X_test.index)

#Extracting False Positive and True Positive rates for ROC curve plotting
fpr_dtree, tpr_dtree, threshold_dtree = roc_curve(y_test, prob_test_dtree.class_1)

#Calculating area under the curve
roc_auc_dtree = auc(fpr_dtree, tpr_dtree)
print(f"Area under curve (AUC): {roc_auc_dtree:.3f}")

#Showing precision and recall from classification report
print(classification_report(y_test,y_pred_test))
# Out:
# Accuracy score: 0.760
# Area under curve (AUC): 0.827
#               precision    recall  f1-score   support
#
#            0       0.77      0.75      0.76       307
#            1       0.75      0.77      0.76       305
#
#    micro avg       0.76      0.76      0.76       612
#    macro avg       0.76      0.76      0.76       612
# weighted avg       0.76      0.76      0.76       612

# %% [markdown]
# #### Comparison of Logistic Regression and Decision Tree ROC & Precision-Recall Curve

# %%
#ROC curve for high salary prediction (class 1)
fig, ax = plt.subplots(figsize=(6, 6))
sns.lineplot(fpr_dtree, tpr_dtree, label='ROC curve Decision tree (area = %0.2f)' % roc_auc_dtree, linewidth=4,color='red')
sns.lineplot(fpr, tpr, label='ROC curve Logistic Regression (area = %0.2f)' % roc_auc, linewidth=4,color='purple')
plt.plot([0, 1], [0, 1], 'k--', linewidth=4)
plt.xlim([-0.05, 1.0])
plt.ylim([-0.05, 1.01])
plt.xlabel('False Positive Rate', fontsize=18)
plt.ylabel('True Positive Rate', fontsize=18)
plt.title('ROC curve', fontsize=18)
plt.legend(loc="lower right")
plt.savefig("./images/ROC.png");

# %% [markdown]
# #### Precision-Recall Curve

# %%
#Extracting Precision and Recall values for curve plotting
precision_dtree, recall_dtree, threshold_dtree = precision_recall_curve(y_test, prob_test_dtree.class_1)

# Precision-recall curve for high salary prediction (class 1)
fig, ax = plt.subplots(figsize=(6, 6))
sns.lineplot(recall_dtree, precision_dtree, label='Precision-recall curve - Decision Tree', linewidth=4,color='r',ax=ax)
sns.lineplot(recall, precision, label='Precision-recall curve - Logistic Regression', linewidth=4,color='g',ax=ax)
plt.xlim([-0.01, 1.01])
plt.ylim([-0.01, 1.01])
plt.xlabel('Recall', fontsize=18)
plt.ylabel('Precision', fontsize=18)
plt.vlines(0.7,-0.01,1.1,label="")
plt.hlines(0.90,-0.01,1.1,label="90% precision")
plt.title('Precision-Recall curve', fontsize=18)
plt.legend(loc="lower right")
plt.savefig("./images/Precision-Recall.png");

# %%
recall_dtree.shape
# Out:
# (24,)

# %% [markdown]
# ### Summarize your results in an executive summary written for a non-technical audience.
#
# - Writeups should be at least 500-1000 words, defining any technical terms, explaining your approach, as well as any risks and limitations.

# %% [markdown]
# #### Background
# DataRecruit Intl., British recruiters for ``elite Data Professionals in industry`` has approached **GA technology solutions** to build a model to predict accurately whether jobs posted online are high or low relative to the median global salary for Data related jobs. They have made a baseline requirement that what ever **the model predicts should be 90% precise when determining high salary jobs** as this is what is important to their clients and their own reputation.

# %% [markdown]
# #### Approach
# **GA technology solutions** has taken the approach to web scrape known Data Science job postings with salary information from 4 major countries where Data Scientists operate from Indeed.com. Over 3,000 jobs were identified and care was taken to convert the salary information for the respective currency exchange rates to the firms local currency (£). The raw data captured was:
# 1. Annualized equivalent salary - **Target Variable**
# - Job Category (e.g Data Scientist, Data Analyst, Machine Learning Engineer)
# - Job Level (e.g Senior, Junior, Principal)
# - Job Region (e.g NorthEast USA, South Australia, Alberta)
# - Country where the job was posted (e.g USA, UK, Canada, Australia)
# - The full job description and summary
#
# The exploratory data analysis indicate that job levels (Senior and Mid) and job category (Data Scientist and Data Analyst) maybe good features for segregating high salary jobs from low because of the differences in the median of their histograms below:
#
# <table><tr><td><img src='./images/data_science.png'><figcaption><b>Figure 1a</b></figcaption></td><td><img src='./images/level.png'><figcaption><b>Figure 1b</b></figcaption></td></tr></table><br>
# <table><tr><td><img src='./images/country.png'><figcaption><b>Figure 1c</b></figcaption></td><td><img src='./images/region.png'><figcaption><b>Figure 1d</b></figcaption></td></tr></table><br>
#
# ##### Target Variable
# The target or dependent variable was then converted to 1's and 0's with 1 representing a high salary job (> £50,000) and 0 representing a low salary job (< £50,000). £50,000 was determined to be the median data related salary for the jobs surveyed.
#
# ##### Predictor Variables
# Each independent variable or predictor listed above was converted from a categorical variable (having labels) to a numeric vector of 1's and 0's (binarized) to indicate the presence of the label in a job positing. This was also done using every word in the full job description by the process of Term Frequency Inverse Document Frequency (Tfidf) which determined the relative density of particular words within all job postings. The most frequent 500 words which showed up more often than 0.2% of the time and less often than 90% of the time were used for the model input.
#
# This combined matrix of numeric vectors representing words and variables was then used as the input to two models that were selected, 1) A logistic regression model and 2) A decision tree model
#
# The 3000+ job postings information was then split into two parts: 1) 80% of the data was split to train or fit the models 2) the remaining 20% was used to test the model on unseen data.

# %% [markdown]
# #### Results
# ##### Initial Predictions
# Using the logistic regression model the results gave an initial accuracy of 83.4% on cross validated training data suggesting that for every 100 job postings we are asked to predict, roughly 83 would be the correct classification (high or low).<br>
# <br>
# The decision tree  model results were not as accurate with 73.9% on cross validated training data (i.e 74 correct classifications). These predictions however were for an untuned model.

# %% [markdown]
# ##### Tuning of Models
# Using the a trial and error procedure in the form of a process called GridSearch, we attempted to tune both models hyperparameters to improve their accuracy. These hyperparameters were adjusted to ultimately search for the combination of components that would deliver the highest cross validated accuracy on the training data.
#
# The tuned logistic regression model improved its accuracy to 84.1% and the decision tree  model improved its accuracy to 75%. This indicated that not much optimization/regularization was needed from initial model hyperparameters.
#
# When testing both models on unseen data (test data) out of 612 job postings:<br>
# - The logistic regression model classified 516 job postings correctly as high/low salary jobs<br>
# - The decision tree model classified only 469 job postings correctly as high/low salary jobs

# %% [markdown]
# ##### Factors which determined high salary jobs
#
# From the logistic regression model the following factors were seen to increase the odds that a job posting is classified as having a high salary:
#
# 1. Job postings that explicitly place job level criteria such as ``Principal``, ``Senior`` and ``Lead`` in its title.
# - Job postings from the ``United States`` or ``Australia``.
# - Job postings that fall into the job category of ``Data Scientist``or ``Machine Learning``
# - Job postings from the region ``South Australia``, ``Saskatchewan``, ``Ontario``, ``Queensland``, ``Western USA`` or ``NorthEast USA``
# - Job postings which have words like ``london``,``complex``,``contract``,``5 years`` or ``experienced``
#
# <table><tr><td><img src='./images/logistic_coef.png'><figcaption><b>Figure 2a</b></figcaption></td><td><img src='./images/logistic_words.png'><figcaption><b>Figure 2b</b></figcaption></td></tr></table><br>

# %% [markdown]
# From the Decision tree model the following were important features of the job ad for determining high salary jobs:
#
# A job ad that....
# 1. **EITHER** mentioned the word ``5 years`` often in its job description but the posting didn't originate from the ``United Kingdom`` and didnt mention the word ``machine`` much in its job description.<br>
#
# 2. **OR** mentioned the word ``machine`` often in its job description but didn't mentioned the words ``uk`` and ``life`` much.
#
# 3. **OR** mentioned the word ``machine`` and ``uk`` often in its job description but didn't mentioned the word ``required`` much.
#
# > - The word ``machine`` in a job description contributed **~20%** to the separation of high salary jobs from low salary jobs
# > - Job postings originating from the ``United Kingdom`` contributes **~12.2%** to the separation of high salary jobs from low salary jobs
# > - The word ``5 years`` in its job description contributed **~6%** to the separation of high salary jobs from low salary jobs
#
# <table><tr><td><img src='./images/decision_tree.png'><figcaption><b>Figure 3</b></figcaption></td></tr></table><br>

# %% [markdown]
# ##### Model Precision
#
# The models precision scores for predicting high salary jobs were 82% and 75% precision for the Logistic Regression model Decision Tree Model respectively. **This fell below the 90% precision requirement specified by the client.**
#
# To address this the **probability threshold for identifying a high salary job was adjusted**. The current setting for the levels of precision seen was 0.5 (meaning any probability determined for a given observation for the high salary class that was greater than 0.5 would be classified as high salary).
#
# **This default threshold was adjusted to 0.75** (meaning any probability determined for a given observation for the high salary class that was greater than 0.75 would be classified as high salary - anything below this would be designated as low salary)
#
# Looking at the Receiver Operating Curve (ROC) and the Precision Recall Curve for both models in Figure 4, the Logistic Regression model out performs the Decision tree model with respect to having the highest combined precision and recall.
#
# The 90% precision requirement translates to minimizing the False Positive rate to no more than 0.1 (10 wrongly predicted high salary jobs in every 100 truly low salary jobs) and boosting the true positive rate or recall.

# %% [markdown]
# <table><tr><td><img src='./images/ROC.png'><figcaption><b>Figure 4a</b></figcaption></td><td><img src='./images/Precision-Recall.png'><figcaption><b>Figure 4b</b></figcaption></td></tr></table><br>

# %% [markdown]
# #### Risks and Limitations
# There were several risks and limitations of the approach taken which are listed below:
#
# ##### The Data
# **1. Salaries were not adjusted for purchase power parity (PPP)**<br>
# While the salaries were adjusted for exchange rate differences they were not adjusted for purchase power parity (PPP) which would truly give a measure of effective comparison. Additionally, clients looking for different salary levels are interested more in how that salary translates to their disposable income which would be somewhat relected in the PPP.
#
# **2. Jobs with salaries mainly were mid-level and came from the England region**<br>
# The distribution of jobs with salaries that were collected mainly were mid-level and came from England. Other regions and job-levels were underrepresented and thus the classifier may lean heavily on using these features as strong predictors.
#
# ##### Data Processing
#
# **3. Certain High frequency words were not processed in the analysis**<br>
# Although a Tfidvectorizer textual analyzer was used for job summaries, some words of a certain frequency were omitted from the model and could have given further insight/better predictive capacity for job classification
#
#
# ##### Model Selection
# **4. Only two classification models were evaluated in the study**<br>
# Because only two models were evaluated the best type of model would not have been fully explored. Other models could potentially deliver more accurate and precise predictions (KNN, RandomForest, Bagging etc.).

# %% [markdown]
# <img src="http://imgur.com/xDpSobf.png" style="float: left; margin: 25px 15px 0px 0px; height: 25px">
#
# ### BONUS
#
# Convert your executive summary into a public blog post of at least 500 words, in which you document your approach in a tutorial for other aspiring data scientists. Link to this in your notebook.

# %%
## YOUR LINK HERE IN MARKDOWN FORMAT
