# %%
import numpy as np
import pandas as pd

import requests
from bs4 import BeautifulSoup
import re

import time
from tqdm import tqdm_notebook

#Function definitions

def extract_jobtitle_from_result(result):
    try:
        return result.find('a',attrs={'class':'jobtitle'})['title']
    except:
        return np.nan

def extract_location_from_result(result):    
    try:
        return result.find('span',attrs={'class':'location accessible-contrast-color-location'}).text
    except:
        return np.nan
        
def extract_salary_from_result(result):
    try:
        return result.find('span',attrs={'class':"salaryText"}).text.strip() 
    except: 
        return np.nan

def extract_company_from_result(result):
    try:
        return result.find('span',attrs={'class':"company"}).text.strip()  
    except:
        return np.nan
    
def extract_summary_from_result(result):
    try:
        return result.find('div',attrs={'class':re.compile(r'^jobsearch-jobDescriptionText?')})   
    except:
        return np.nan
    
def extract_href_from_result(result):
    try:
        return result.find('a')['href']   
    except:
        return np.nan

# %%
states_to_use = ['British Columbia',
 'Alberta',
 'Saskatchewan',
 'Manitoba',
 'Ontario',
 'Quebec',
 'New Brunswick',
 'Prince Edward Island',
 'Nova Scotia',
 'Newfoundland and Labrador',
 'Yukon',
 'Northwest Territories',
 'Nunavut']


list_of_searchwords = ['data+scientist','data+analyst','research+scientist','business+intelligence','machine+learning']

# %%
#Determining number of jobs per state,region, area etc

jobs_in_state = {'state':[],'role':[],'jobs':[]}

for state in tqdm_notebook(states_to_use):
    
    for role in list_of_searchwords:
    
        count_url = f'https://ca.indeed.com/jobs?as_ttl={role}&jt=all&radius=5000&l={state}&fromage=any&limit=50&filter=0'

        time.sleep(np.random.randint(0,2))

        counter = requests.get(count_url)
        soup_count = BeautifulSoup(counter.text,'html.parser')
        
        if len(soup_count.find_all('div',class_='bad_query'))==1:
            
            pass
        
        else:

            try:
                record_string = soup_count.find_all('div',attrs={'id':"searchCountPages"})[0].text
                record_string = record_string.replace(",","")
                max_results_per_city = int(re.search(r"(\w+)\sjobs",record_string).group(1))

            except:
                max_results_per_city = np.nan

            #try:
                #true_pages = int(soup_count.find_all("span",class_="pn")[-2].text)
                #print(true_pages,max_results_per_city)

            #except:
                #true_pages = 0
                #print(true_pages)

            jobs_in_state['state'].append(state)
            jobs_in_state['role'].append(role)
            jobs_in_state['jobs'].append(max_results_per_city)
# Out:
# HBox(children=(IntProgress(value=0, max=13), HTML(value='')))

# %%
job_nums = pd.DataFrame(jobs_in_state).sort_values(by='jobs',ascending=False)

state_searchlist= job_nums.groupby(["state"]).mean().sort_values(by="jobs",ascending=True).index.to_list()
role_searchlist = job_nums.groupby(["role"]).mean().sort_values(by="jobs",ascending=True).index.to_list()
job_nums
# Out:
#                state                   role  jobs
# 17           Ontario           data+analyst   164
# 16           Ontario         data+scientist   121
# 20           Ontario       machine+learning    64
# 19           Ontario  business+intelligence    62
# 24            Quebec  business+intelligence    49
# 22            Quebec           data+analyst    45
# 21            Quebec         data+scientist    44
# 0   British Columbia         data+scientist    38
# 1   British Columbia           data+analyst    35
# 23            Quebec     research+scientist    24
# 3   British Columbia  business+intelligence    24
# 6            Alberta           data+analyst    23
# 18           Ontario     research+scientist    22
# 4   British Columbia       machine+learning    21
# 25            Quebec       machine+learning    20
# 2   British Columbia     research+scientist    18
# 8            Alberta  business+intelligence    16
# 5            Alberta         data+scientist    12
# 9            Alberta       machine+learning    11
# 13          Manitoba           data+analyst     7
# 30       Nova Scotia           data+analyst     6
# 7            Alberta     research+scientist     3
# 32       Nova Scotia  business+intelligence     3
# 27     New Brunswick     research+scientist     2
# 31       Nova Scotia     research+scientist     2
# 10      Saskatchewan         data+scientist     2
# 14          Manitoba  business+intelligence     2
# 26     New Brunswick           data+analyst     1
# 15          Manitoba       machine+learning     1
# 28     New Brunswick  business+intelligence     1
# 29       Nova Scotia         data+scientist     1
# 11      Saskatchewan           data+analyst     1
# 12          Manitoba         data+scientist     1
# 33       Nova Scotia       machine+learning     1

# %%
df_dict = {'job_title':[],'job_category':[],
           'company':[],'location':[],
           'region':[],'salary':[],
           'link':[],'summary':[]}

#url_template = "http://www.indeed.com/jobs?q=data+scientist+%2420%2C000&l={}&start={}"
max_results_per_city = 294 # Set this to a high-value (5000) to generate more results. 
# Crawling more results, will also take much longer. First test your code on a small number of results and then expand.

all_files = []

for state in tqdm_notebook(state_searchlist):

    for role in tqdm_notebook(role_searchlist):
        
        count_url = f'https://ca.indeed.com/jobs?as_ttl={role}&jt=all&radius=5000&l={state}&fromage=any&limit=50&start=0&filter=0'

        time.sleep(np.random.randint(0,1))

        counter = requests.get(count_url)
        soup_count = BeautifulSoup(counter.text,'html.parser')
        
        if len(soup_count.find_all('div',class_='bad_query'))==1:
            
            pass
        
        else:     

            try:
                record_string = soup_count.find_all('div',attrs={'id':"searchCountPages"})[0].text
                record_string = record_string.replace(",","")
                max_results_per_city = int(re.search(r"(\w+)\sjobs",record_string).group(1))
            except:
                max_results_per_city = 1

            for start in tqdm_notebook(range(0, max_results_per_city,50)):
                time.sleep(np.random.randint(0,1))

                URL = f'https://ca.indeed.com/jobs?as_ttl={role}&jt=all&radius=5000&l={state}&fromage=any&limit=50&start={start}&filter=0'

                results = requests.get(URL)
                soup = BeautifulSoup(results.text,'html.parser')

                #print(city,int(max_results_per_city))

                #print(state,start,soup.find_all('div',attrs={'id':"searchCountPages"})[0].text)

                if len(soup.find_all('span',attrs={'class':'salary no-wrap'})) == 0:

                    pass

                else:
                    for jobtile in soup.find_all('div',attrs={'class':re.compile(r'^jobsearch-Serp.*unified.*')}):

                        if len(jobtile.find_all('span',attrs={'class':'salary no-wrap'})) == 0:
                            pass
                        else:
                            all_files.append(jobtile)
                            df_dict['job_category'].append(" ".join(role.split("+")).title())
                            df_dict['region'].append(" ".join(state.split("+")).title())

                            detail_link = "https://ca.indeed.com/"+extract_href_from_result(jobtile)
                            df_dict['link'].append(detail_link)
                            time.sleep(np.random.randint(0,1))
                            detailgrab = requests.get(detail_link)
                            soup_detail = BeautifulSoup(detailgrab.text,'html.parser')

                            try:
                                df_dict['summary'].append(extract_summary_from_result(soup_detail).text)
                            except:
                                df_dict['summary'].append(np.nan)
# Out:
# HBox(children=(IntProgress(value=0, max=8), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=5), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=1), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=2), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=3), HTML(value='')))
# HBox(children=(IntProgress(value=0, max=4), HTML(value='')))

# %%
for x in all_files:
    try:
        df_dict['location'].append(extract_location_from_result(x))
    except:
        df_dict['location'].append(np.nan)
        
    try:
        df_dict['company'].append(extract_company_from_result(x))
    except:
        df_dict['company'].append(np.nan)
        
    try:
        df_dict['salary'].append(extract_salary_from_result(x))
        
    except:
        df_dict['salary'].append(np.nan)

    try:
        df_dict['job_title'].append(extract_jobtitle_from_result(x))
        
    except:
        df_dict['job_title'].append(np.nan)

# %%
df = pd.DataFrame(df_dict)

np.sum(df[df.salary.notna()].duplicated() ==False)*100/df.shape[0]

#df = df[df.salary.notna()]

#df = df[df.duplicated()==False]

df.to_csv("can_jobs.csv",index=False)

# %%
df[df.duplicated()==False]
# Out:
#                                             job_title           job_category  \
# 0                        Solutions Analyst – ERP Data           Data Analyst
# 1   Research Scientist - Crustal Seismologist AMEN...     Research Scientist
# 2   Veterinary machine learning data collection re...       Machine Learning
# 3   AU-03 Income Tax Business Intelligence and Qua...  Business Intelligence
# 4   AU-03 Income Tax Business Intelligence and Qua...  Business Intelligence
# 5   AU-01 Excise Tax /Income Tax Business Intellig...  Business Intelligence
# 6   Data Analyst, Early Childhood Collaborative Re...           Data Analyst
# 7        Business Intelligence & Business Development  Business Intelligence
# 8     Trauma Data Analyst - Pediatrics & Child Health           Data Analyst
# 9   AU-03 Tax Auditor, Tax Avoidance Auditor, Inte...  Business Intelligence
# 10              Analyst, Data & Reporting (INVENTORY)           Data Analyst
# 11                            Data Management Analyst           Data Analyst
# 12                                Health Data Analyst           Data Analyst
# 13                               Research Scientist I     Research Scientist
# 14                                 Research Scientist     Research Scientist
# 15    Research Scientist: Reactive Transport Modeling     Research Scientist
# 16    Research Scientist: Reactive Transport Modeling     Research Scientist
# 17                                 Research Scientist     Research Scientist
# 18                   Developer, Business Intelligence  Business Intelligence
# 19                                  Data Scientist II         Data Scientist
# 20                                Senior Data Analyst           Data Analyst
# 21                                Senior Data Analyst           Data Analyst
# 22           Data Warehouse Analyst - FTT (13 months)           Data Analyst
# 23                             Data Warehouse Analyst           Data Analyst
# 24  Senior Research Scientist, Drug Metabolism and PK     Research Scientist
# 25  Business Intelligence Specialist - Technology ...  Business Intelligence
# 26                                     Data Scientist         Data Scientist
# 27               Data Loss Prevention Analyst 3138075           Data Analyst
# 28                              Data Analyst (MR0272)           Data Analyst
# 29                 Enrolment Data and Process Analyst           Data Analyst
# 30                                 Research Scientist     Research Scientist
# 31  APPLIED RESEARCH SCIENTIST – Electrochemical P...     Research Scientist
# 32      Poultry Modeling Nutrition Research Scientist     Research Scientist
# 33       Research Scientist - Wildland Fire Scientist     Research Scientist
# 34                          Senior Research Scientist     Research Scientist
# 35  APPLIED RESEARCH SCIENTIST – Electrochemical P...     Research Scientist
# 36        Inclusive Developer (AI & Machine Learning)       Machine Learning
# 37                 Machine Learning Engineer — Intern       Machine Learning
# 38                          Machine Learning Engineer       Machine Learning
# 39      Senior Project Manager, Business Intelligence  Business Intelligence
# 40                Jr. Business Intelligence Developer  Business Intelligence
# 41               Business Intelligence (BI) Developer  Business Intelligence
# 42            Senior Business Intelligence Specialist  Business Intelligence
# 43   Practice Lead – Business Intelligence (Power BI)  Business Intelligence
# 44                             Data Scientist Advisor         Data Scientist
# 45                                 Sr. Data Scientist         Data Scientist
# 46                                     Data Scientist         Data Scientist
# 47                              Senior Data Scientist         Data Scientist
# 48                                       Data Analyst           Data Analyst
# 49      Data Analyst, Metrics and Market Intelligence           Data Analyst
# 50                              Business Data Analyst           Data Analyst
# 51                                 Space Data Analyst           Data Analyst
# 52  Social Investment Data & Research Analyst/Spec...           Data Analyst
# 53                                Junior Data Analyst           Data Analyst
# 54                             Marketing Data Analyst           Data Analyst
# 55  BILINGUAL ANALYST, EDUCATION DATA AND RESEARCH...           Data Analyst
#
#                                               company              location  \
# 0                                   City of Saskatoon         Saskatoon, SK
# 1                            Natural Resources Canada         Dartmouth, NS
# 2                                            Talkatoo           Halifax, NS
# 3                               Canada Revenue Agency         Dartmouth, NS
# 4                               Canada Revenue Agency         Dartmouth, NS
# 5                               Canada Revenue Agency         Dartmouth, NS
# 6                      Mount Saint Vincent University           Halifax, NS
# 7                                           Catchfire          Winnipeg, MB
# 8                              Health Sciences Centre          Winnipeg, MB
# 9                               Canada Revenue Agency          Edmonton, AB
# 10           Employment and Social Development Canada           Calgary, AB
# 11                                   City of Edmonton          Edmonton, AB
# 12            Alberta Bone and Joint Health Institute           Calgary, AB
# 13                     AMZN CAN Fulfillment Svcs, ULC         Vancouver, BC
# 14                       Applied Biological Materials          Richmond, BC
# 15                     University of British Columbia         Vancouver, BC
# 16                                         UBC Sauder         Vancouver, BC
# 17                   Applied Biological Materials Inc          Richmond, BC
# 18                    University of the Fraser Valley        Abbotsford, BC
# 19                     AMZN CAN Fulfillment Svcs, ULC         Vancouver, BC
# 20                     University of British Columbia         Vancouver, BC
# 21                                         UBC Sauder         Vancouver, BC
# 22                                          TransLink    Lower Mainland, BC
# 23                             Dynamic Solutions Inc.          Victoria, BC
# 24                                Nuchem Therapeutics          Montréal, QC
# 25                                     Morgan Stanley          Montréal, QC
# 26                                            MAXA AI          Montréal, QC
# 27                                     Morgan Stanley          Montréal, QC
# 28             McGill University, Faculty of Medicine          Montréal, QC
# 29                                Bishop's University        Sherbrooke, QC
# 30                                      Health Canada            Ottawa, ON
# 31                                    Lambton College            Sarnia, ON
# 32                                            Nutreco            Guelph, ON
# 33                           Natural Resources Canada  Sault Ste. Marie, ON
# 34                              Cafco Industries Inc.       Scarborough, ON
# 35                                    Lambton College            Sarnia, ON
# 36                                    OCAD University           Toronto, ON
# 37                                            Alexsei           Toronto, ON
# 38                                          CTO Boost           Toronto, ON
# 39                                    Sterling-Turner           Toronto, ON
# 40                                    Sterling-Turner           Toronto, ON
# 41                                    Sterling-Turner           Toronto, ON
# 42                                    Sterling-Turner           Toronto, ON
# 43                                    Sterling-Turner           Toronto, ON
# 44                                               CMHC            Ottawa, ON
# 45                                            Precima           Toronto, ON
# 46                               Prodigy Systems Inc.           Toronto, ON
# 47                              Digital Extremes Ltd.            London, ON
# 48                                     City of Ottawa            Ottawa, ON
# 49                               Ivey Business School            London, ON
# 50                                    Sterling-Turner           Toronto, ON
# 51                             University of Waterloo          Waterloo, ON
# 52                                    City of Windsor           Windsor, ON
# 53                                  Nexus Energy Inc.           Toronto, ON
# 54                                    Meridian Canada       Mississauga, ON
# 55  THE COUNCIL OF MINISTERS OF EDUCATION, CANADA ...           Toronto, ON
#
#               region                      salary  \
# 0       Saskatchewan   $90,556 - $104,530 a year
# 1        Nova Scotia   $55,870 - $144,413 a year
# 2        Nova Scotia                 $20 an hour
# 3        Nova Scotia    $81,525 - $99,065 a year
# 4        Nova Scotia    $81,525 - $99,065 a year
# 5        Nova Scotia    $59,674 - $78,134 a year
# 6        Nova Scotia           $24 - $26 an hour
# 7           Manitoba   $30,280 - $129,381 a year
# 8           Manitoba              $22.88 an hour
# 9            Alberta    $81,525 - $99,065 a year
# 10           Alberta    $61,558 - $66,324 a year
# 11           Alberta     $48.11 - $61.39 an hour
# 12           Alberta    $60,000 - $80,000 a year
# 13  British Columbia   $79,600 - $133,000 a year
# 14  British Columbia   $60,000 - $120,000 a year
# 15  British Columbia              $53,019 a year
# 16  British Columbia              $53,019 a year
# 17  British Columbia   $60,000 - $120,000 a year
# 18  British Columbia     $4,939 - $5,805 a month
# 19  British Columbia   $88,200 - $147,300 a year
# 20  British Columbia              $75,507 a year
# 21  British Columbia              $75,507 a year
# 22  British Columbia              $39.53 an hour
# 23  British Columbia              $70,000 a year
# 24            Quebec    $75,000 - $95,000 a year
# 25            Quebec  $150,000 - $185,000 a year
# 26            Quebec    $50,000 - $80,000 a year
# 27            Quebec   $85,000 - $100,000 a year
# 28            Quebec    $56,800 - $92,500 a year
# 29            Quebec     $27.72 - $36.19 an hour
# 30           Ontario   $55,870 - $144,413 a year
# 31           Ontario              $31.37 an hour
# 32           Ontario    $80,000 - $90,000 a year
# 33           Ontario   $55,870 - $144,413 a year
# 34           Ontario             $174,410 a year
# 35           Ontario              $31.37 an hour
# 36           Ontario    $61,203 - $80,438 a year
# 37           Ontario                 $17 an hour
# 38           Ontario    $80,000 - $91,000 a year
# 39           Ontario  $254,000 - $259,000 a year
# 40           Ontario   $90,000 - $150,000 a year
# 41           Ontario  $210,000 - $215,000 a year
# 42           Ontario  $260,000 - $268,000 a year
# 43           Ontario  $380,000 - $384,000 a year
# 44           Ontario  $111,374 - $139,217 a year
# 45           Ontario   $85,000 - $100,000 a year
# 46           Ontario           $70 - $85 an hour
# 47           Ontario   $70,000 - $140,000 a year
# 48           Ontario    $70,947 - $86,326 a year
# 49           Ontario    $51,300 - $64,200 a year
# 50           Ontario  $174,000 - $175,000 a year
# 51           Ontario    $56,181 - $70,226 a year
# 52           Ontario     $26.79 - $31.48 an hour
# 53           Ontario              $60,000 a year
# 54           Ontario    $40,000 - $50,000 a year
# 55           Ontario    $62,011 - $86,697 a year
#
#                                                  link  \
# 0   https://ca.indeed.com//rc/clk?jk=1ac51de68c153...
# 1   https://ca.indeed.com//rc/clk?jk=8cc4bb5bf127c...
# 2   https://ca.indeed.com//rc/clk?jk=b13f3e443a175...
# 3   https://ca.indeed.com//rc/clk?jk=3c788ea53e61a...
# 4   https://ca.indeed.com//rc/clk?jk=05d44e915017d...
# 5   https://ca.indeed.com//rc/clk?jk=813af33e2263c...
# 6   https://ca.indeed.com//rc/clk?jk=f7b160fa6b790...
# 7   https://ca.indeed.com//company/Catchfire/jobs/...
# 8   https://ca.indeed.com//rc/clk?jk=840e9f2043798...
# 9   https://ca.indeed.com//rc/clk?jk=ea8616f9b7e24...
# 10  https://ca.indeed.com//rc/clk?jk=2156302e15517...
# 11  https://ca.indeed.com//rc/clk?jk=4c4212aab3543...
# 12  https://ca.indeed.com//company/Alberta-Bone-an...
# 13  https://ca.indeed.com//rc/clk?jk=5883218c5896a...
# 14  https://ca.indeed.com//rc/clk?jk=b6a16d56c231a...
# 15  https://ca.indeed.com//rc/clk?jk=784067c450766...
# 16  https://ca.indeed.com//rc/clk?jk=0eef35c700b95...
# 17  https://ca.indeed.com//rc/clk?jk=262ab25bef317...
# 18  https://ca.indeed.com//rc/clk?jk=175c881123cad...
# 19  https://ca.indeed.com//rc/clk?jk=8403771f2bb57...
# 20  https://ca.indeed.com//rc/clk?jk=9b022ac5ce7c8...
# 21  https://ca.indeed.com//rc/clk?jk=46d3ea65fc301...
# 22  https://ca.indeed.com//rc/clk?jk=54568cc85d347...
# 23  https://ca.indeed.com//rc/clk?jk=df563a21a377c...
# 24  https://ca.indeed.com//company/NuChem-Therapeu...
# 25  https://ca.indeed.com//rc/clk?jk=de27a8ad89ad8...
# 26  https://ca.indeed.com//company/MAXA-AI/jobs/Da...
# 27  https://ca.indeed.com//rc/clk?jk=429e365ca272b...
# 28  https://ca.indeed.com//company/McGill-Universi...
# 29  https://ca.indeed.com//rc/clk?jk=9af3503f4c3c5...
# 30  https://ca.indeed.com//rc/clk?jk=e67b6ec2e6f34...
# 31  https://ca.indeed.com//rc/clk?jk=0e6881842cebe...
# 32  https://ca.indeed.com//rc/clk?jk=10dcdfafcfc0d...
# 33  https://ca.indeed.com//rc/clk?jk=301f889aea954...
# 34  https://ca.indeed.com//company/Cafco-Industrie...
# 35  https://ca.indeed.com//rc/clk?jk=d526fa83455de...
# 36  https://ca.indeed.com//rc/clk?jk=5e56cbf59e763...
# 37  https://ca.indeed.com//rc/clk?jk=46c7bf5e3b76b...
# 38  https://ca.indeed.com//company/CTO-Boost/jobs/...
# 39  https://ca.indeed.com//rc/clk?jk=97861e8ba6569...
# 40  https://ca.indeed.com//rc/clk?jk=40bafb7ee2ea8...
# 41  https://ca.indeed.com//rc/clk?jk=443a7d7359232...
# 42  https://ca.indeed.com//rc/clk?jk=22e6ef9311778...
# 43  https://ca.indeed.com//rc/clk?jk=cee68fa9c96c6...
# 44  https://ca.indeed.com//rc/clk?jk=5dc57a2ac6aa3...
# 45  https://ca.indeed.com//rc/clk?jk=1d541b06d0e2d...
# 46  https://ca.indeed.com//company/Prodigy-Systems...
# 47  https://ca.indeed.com//company/Digital-Extreme...
# 48  https://ca.indeed.com//rc/clk?jk=b24e39b5ac2d6...
# 49  https://ca.indeed.com//rc/clk?jk=fae610b0303c3...
# 50  https://ca.indeed.com//rc/clk?jk=bb662232d749e...
# 51  https://ca.indeed.com//rc/clk?jk=f641a8e9c9b63...
# 52  https://ca.indeed.com//rc/clk?jk=4f90831c33d71...
# 53  https://ca.indeed.com//company/Nexus-Energy-In...
# 54  https://ca.indeed.com//company/Meridian-Canada...
# 55  https://ca.indeed.com//company/Council-of-Mini...
#
#                                               summary
# 0   Duties:\nConsults with the ERP Portfolio Leads...
# 1   Natural Resources Canada - Lands and Minerals ...
# 2   This 2day 16-hour gig that involves working wi...
# 3   Pour obtenir une description des termes clés u...
# 4   For a description of key terms used on CRA job...
# 5   About the job\nDon’t miss out on your opportun...
# 6   Dr. Jessie-Lee McIsaac, Assistant Professor wi...
# 7   If you are highly motivated, self-directed, un...
# 8   Requisition ID: 34677\nPosition Number: 200172...
# 9   For a description of key terms used on CRA job...
# 10  Employment and Social Development Canada - Inn...
# 11  Description\nData Management Analyst\nJob Numb...
# 12  NOTE: This position is a 1-year term to back f...
# 13  7+ years of software development experienceBac...
# 14  Recognized as one of the Fastest-Growing Compa...
# 15  Job Posting\n\nJob ID:\n\n35677\n\n\n\nLocatio...
# 16  Job Posting\n\nJob ID:\n\n35677\n\n\n\nLocatio...
# 17  Recognized as one of the Fastest-Growing Compa...
# 18  The Department of Institutional Research and P...
# 19  Master or PhD in Computer Science, Machine Lea...
# 20  Job Posting\n\nJob ID:\n\n35717\n\n\n\nLocatio...
# 21  Job Posting\n\nJob ID:\n\n35717\n\n\n\nLocatio...
# 22  The South Coast British Columbia Transportatio...
# 23  About Us\n\nDynamic Solutions is a software de...
# 24  Senior Research Scientist, Drug Metabolism and...
# 25  Company Profile\n\nMorgan Stanley is a leading...
# 26  MAXA AI is looking for a full-time Data Scient...
# 27  Company Profile\n\nMorgan Stanley is a global ...
# 28  Position Summary: Medical Educational Services...
# 29  Posting 19-49 (Temporary full-time position)\n...
# 30  Health Canada - Healthy Environments and Consu...
# 31  This is a full-time Support Staff Bargaining U...
# 32  Canada\nWould you like to join one of the worl...
# 33  Natural Resources Canada - Canadian Forest Ser...
# 34  Business: Cafco Industries Inc.Position: Senio...
# 35  Company Biography:\nLambton College is a natio...
# 36  Project Summary:\n\nData and algorithms aren't...
# 37  Alexsei is a legal AI startup that provides an...
# 38  CTO Boost is looking for our next rockstar Mac...
# 39  Senior Project Manager, Business Intelligence\...
# 40  Jr. Business Intelligence Developer\nLocation:...
# 41  Business Intelligence (BI) Developer\nLocation...
# 42  Senior Business Intelligence Specialist\nLocat...
# 43  Practice Lead – Business Intelligence (Power B...
# 44  Sector: Information Technology\nLanguage Desig...
# 45  Employer: Loyalty One Position: Senior Data Sc...
# 46  This person will be working with 5 different D...
# 47  You will: Work within an amazing team using da...
# 48  Position: Data Analyst\n\nCompetition Number: ...
# 49  Who you are:\nAs the Data Analyst, Metrics and...
# 50  Business Data Analyst\nLocation: Toronto/GTA, ...
# 51  Overview\nTerm: 1 year\n\nReporting to the Man...
# 52  JOB POSTING #: 2019-0278\nPOSTING PERIOD: Thur...
# 53  Nexus Energy Inc. operates in both the physica...
# 54  Meridian Canada is a quality manufacturer of w...
# 55  THE COUNCIL OF MINISTERS OF EDUCATION, CANADA ...

# %%
url = 'https://api.exchangeratesapi.io/latest'

requests.get(url,params={"base":"GBP"}).json()
# Out:
# {'rates': {'CAD': 1.6756738031,
#   'HKD': 10.0519642486,
#   'ISK': 159.7034573547,
#   'PHP': 65.7647982632,
#   'DKK': 8.6265271715,
#   'HUF': 379.7662763574,
#   'CZK': 29.5249312917,
#   'GBP': 1.0,
#   'RON': 5.4912353634,
#   'SEK': 12.4073304233,
#   'IDR': 18001.1894039123,
#   'INR': 90.9391671863,
#   'BRL': 5.1654772628,
#   'RUB': 81.7847987251,
#   'HRK': 8.6064343287,
#   'JPY': 139.2526386291,
#   'THB': 38.6891152221,
#   'CHF': 1.272431234,
#   'EUR': 1.1547610799,
#   'MYR': 5.368946165,
#   'BGN': 2.2584817201,
#   'TRY': 7.3918566249,
#   'CNY': 9.0676459041,
#   'NOK': 11.7629737407,
#   'NZD': 2.0157509411,
#   'ZAR': 18.7518187487,
#   'USD': 1.2825931315,
#   'MXN': 24.4832444167,
#   'SGD': 1.748308275,
#   'AUD': 1.8787962771,
#   'ILS': 4.5315134299,
#   'KRW': 1506.8130903716,
#   'PLN': 4.9397214716},
#  'base': 'GBP',
#  'date': '2019-10-25'}

# %%
params = dict(
  client_id= client_id,
  client_secret=client_secret,
  v='20180323',
  ll='51.515086,-0.072265',
  query='steak',
  limit=10
